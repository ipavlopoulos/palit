# %% [markdown]
# <a href="https://colab.research.google.com/github/ipavlopoulos/palit/blob/main/code/fcnnc--fragment-level-split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import libraries

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset, TensorDataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import skimage
from skimage import transform
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import *
from sklearn.model_selection import GroupShuffleSplit, train_test_split
from sklearn.metrics import confusion_matrix
import xgboost as xgb

from tqdm.notebook import tqdm
import os
import random

# %% [markdown]
# #### Classifier and training Utilities

# %%
class CNNCLF(nn.Module):
    def __init__(self, n_classes):
        super().__init__()

        self.CNN = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=0),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),
            nn.BatchNorm2d(32),

            nn.Conv2d(32, 64, kernel_size=5),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2, 2),
        )

        self.MLP = nn.Sequential(
            nn.Linear(41472, 1024, bias=True),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(1024),
            nn.Dropout(p=0.1, inplace=True),

            nn.Linear(1024, 512, bias=True),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(512),
            nn.Dropout(p=0.1, inplace=True),

            nn.Linear(512, n_classes, bias=True)
        )

    def forward(self, x):
        x = self.CNN(x.unsqueeze(1))
        x = torch.flatten(x, 1)
        x = self.MLP(x)
        return x

# %%
# the model predicts the average - high variance
def validate_clf(model, dataloader, device="cpu", criterion = nn.CrossEntropyLoss()):
    prediction_list, labels_list = [], []
    model.eval()
    loss = 0
    with torch.no_grad():
        for id_batch, (inputs, labels) in enumerate(dataloader):
            inputs, labels = inputs.to(device), labels.to(device)
            model.to(device)
            outputs = model(inputs)
            loss += criterion(outputs, labels).item()
            labels = np.argmax(labels.cpu().detach().numpy(), axis=1)
            predictions = np.argmax(outputs.cpu().detach().numpy(), axis=1)
            prediction_list.append(predictions)
            labels_list.append(labels)
    p = np.concatenate(prediction_list)
    g = np.concatenate(labels_list)
    acc = accuracy_score(g, p)
    return p, g, loss, acc

def train_clf(model, dataloader, optimizer, criterion=nn.CrossEntropyLoss(), val_dataloader=None, patience=3, N_EPOCHS=100, device="cpu"):
    losses, mae_losses, val_losses, train_losses = [], [], [], []
    dataset_size = len(dataloader.dataset)
    lowest_error = 100000
    best_epoch = -1

    for epoch in range(N_EPOCHS):
        print(f"\nEpoch {epoch + 1}\n-------------------------------")
        train_loss = 0
        # Loop over batches in an epoch using DataLoader
        for id_batch, (inputs, labels) in enumerate(dataloader):
            model.train()
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        if val_dataloader is not None:
            if (patience>0) and (epoch-best_epoch>patience-1) and epoch > 50:
                print("Max patience reached, now loading the best checkpoint...")
                model.load_state_dict(torch.load("checkpoint.pt"))
                print("Exiting...")
                break
            predictions, labels, val_loss, val_acc = validate_clf(model, val_dataloader, device=device)
            val_losses.append(val_loss)
            train_losses.append(train_loss)
            # ignore majority perfomance
            if (patience>0) and (val_loss<lowest_error):
                lowest_error = val_loss
                best_epoch = epoch
                torch.save(model.state_dict(), "checkpoint.pt")
            print(f"Train loss: {train_loss:.2f}, Val loss: {val_loss:.2f}, Val acc: {val_acc:.2f}")
            print(f"Best Epoch: {best_epoch+1} (Val loss: {lowest_error:.2f})")
            print(f"[val var: {np.var(predictions):.2f}, min-max: {min(predictions):.2f}-{max(predictions):.2f}]")
    model.eval()
    return model, train_losses, val_losses

# %% [markdown]
# #### Data

# %%
class ImageDataset(TensorDataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
        self.labels = np.array(self.dataframe['date'])
        self.labels = np.reshape(self.labels, (self.labels.shape[0], 1))
        self.labels = OneHotEncoder(sparse=False).fit_transform(self.labels)

    def __len__(self):
        return self.dataframe.shape[0]

    def __getitem__(self, idx):
        sample, date = self.dataframe.iloc[idx].img.astype(np.float32), self.labels[idx]
        if self.transform is not None:
            sample = self.transform(sample)
            sample = sample.reshape(sample.shape[1], sample.shape[2]) # grayscale
        return sample, date # 1CE-4CE

# %%
# ACTION needed: download the data (with gdown or re-create using PaLit.xlsx)
# !gdown 1kNgqJCFZS4Q-P2YSaeaYp9P2bTobyOCV
pll = pd.read_pickle("pll.csv")

# %%
dataset = pll.explode("img")
dataset = dataset[dataset.img.notna()]
dataset.sample()
# Out:
#      uid date    quarter              filename_enc  \
# 165  166    4  after 329  4thAD_P.Oxy. 4143(1).jpg
#
#                    filename_websafe  \
# 165  4thAD_P.Oxy.%204143%281%29.jpg
#
#                                                    img
# 165  [[0.3838066666666667, 0.30482470588235294, 0.2...

# %%
print("Lines num:", dataset.shape[0])

w,h = 300,50
img_data = pd.DataFrame(dataset.img.apply(lambda x: x.shape).tolist(), index=dataset.index, columns=["H", "W"])
dataset = dataset[(img_data.W>w)&(img_data.H>h)]
dataset.insert(0, "lid", range(1, dataset.shape[0]+1))
# Out:
# Lines num: 4717

# %% [markdown]
# # Dataset split

# %%
# disregard fragments and split the lines
#pll_train, pll_test = train_test_split(dataset, test_size=0.1, random_state=2023)
#pll_train, pll_val = train_test_split(pll_train, test_size=pll_test.shape[0], random_state=2023)
#print(pll_train.shape[0], pll_val.shape[0], pll_test.shape[0])
# Out:
# 2218 278 278

# %%
dataset.date.value_counts(normalize=True)*100
# Out:
# 2    42.213410
# 3    38.392213
# 1    12.653208
# 4     6.741168
# Name: date, dtype: float64

# %%
# creating a test set with lines from unseen fragments
test_idx = set()
test_idx.update(dataset[dataset.date==1].uid.value_counts(ascending=True).iloc[0:2].index)
test_idx.update(dataset[dataset.date==2].uid.value_counts(ascending=True).iloc[0:10].index)
test_idx.update(dataset[dataset.date==3].uid.value_counts(ascending=True).iloc[0:10].index)
test_idx.update(dataset[dataset.date==4].uid.value_counts(ascending=True).iloc[0:1].index)
pll_test = dataset[dataset.uid.isin(test_idx)]
pll_train = dataset[~dataset.uid.isin(test_idx)]

# %%
# validation set with limited data leakage
val_idx = set()
val_idx.update(pll_train[pll_train.date==1].uid.value_counts(ascending=True).iloc[:1].index)
val_idx.update(pll_train[pll_train.date==2].uid.value_counts(ascending=True).iloc[:1].index)
val_idx.update(pll_train[pll_train.date==3].uid.value_counts(ascending=True).iloc[:1].index)
#val_idx.update(pll_train[pll_train.date==4].uid.value_counts(ascending=True).iloc[:1].index)
pll_val_clean = pll_train[pll_train.uid.isin(val_idx)]
pll_train = pll_train[~pll_train.uid.isin(val_idx)]
pll_train, pll_val_leaked = train_test_split(pll_train, test_size=0.05, random_state=2023)
pll_val = pd.concat([pll_val_clean, pll_val_leaked])

# %%
print(pll_train.shape[0], pll_test.shape[0], pll_val.shape[0])
pd.DataFrame({'train':pll_train.date.value_counts(),
              'test': pll_test.date.value_counts(),
              'val': pll_val.date.value_counts()}).plot.pie(subplots=True, autopct=f'%.0f');
# Out:
# 2516 105 153

# %%
augment = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomAffine(3), # turn
    transforms.RandomResizedCrop((50, 300), scale=(0.75, 1.0), ratio=(1, 6)), # crop n scale (add scale to control this)
    #transforms.RandomCrop((30, 30)),
    transforms.GaussianBlur(3), # blur
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.5, value=0.5), # erase
])

cc_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.CenterCrop((50, 300)),
    transforms.ToTensor(),
])

rs_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((50,300)),
    transforms.ToTensor(),
])

white_fragment_ablation = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((50,300)),
    transforms.ToTensor(),
    transforms.RandomErasing(p=1, value=0), # erase
])

black_fragment_ablation = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((50,300)),
    transforms.ToTensor(),
    transforms.RandomErasing(p=1, value=1), # erase
])

# %% [markdown]
# #### Load Model

# %%
#model = Classifier(n_classes=4)
#model.load_state_dict(torch.load('./checkpoint.pt'))

# %% [markdown]
# ### Training Procedure

# %%
epochs, batch_size, device, n_classes, lr, patience = 150, 16, "cuda", 4, 1e-3, 10
dataloader = DataLoader(ImageDataset(pll_train, transform=augment), batch_size=batch_size, drop_last=False, shuffle=True)
val_dataloader = DataLoader(ImageDataset(pll_val, transform=rs_transform), batch_size=batch_size, drop_last=False)
model = CNNCLF(n_classes=n_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
model, train_losses, val_losses = train_clf(device=device, dataloader=dataloader, model=model, optimizer=optimizer, N_EPOCHS=epochs, val_dataloader=val_dataloader, patience=patience)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1
# -------------------------------
# Train loss: 188.23, Val loss: 11.41, Val acc: 0.47
# Best Epoch: 1 (Val loss: 11.41)
# [val var: 0.03, min-max: 1.00-2.00]
# Epoch 2
# -------------------------------
# Train loss: 170.09, Val loss: 16.93, Val acc: 0.33
# Best Epoch: 1 (Val loss: 11.41)
# [val var: 0.10, min-max: 1.00-2.00]
# Epoch 3
# -------------------------------
# Train loss: 163.91, Val loss: 10.82, Val acc: 0.49
# Best Epoch: 3 (Val loss: 10.82)
# [val var: 0.14, min-max: 0.00-2.00]
# Epoch 4
# -------------------------------
# Train loss: 158.92, Val loss: 10.35, Val acc: 0.52
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.22, min-max: 1.00-2.00]
# Epoch 5
# -------------------------------
# Train loss: 159.64, Val loss: 10.65, Val acc: 0.58
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.33, min-max: 0.00-2.00]
# Epoch 6
# -------------------------------
# Train loss: 147.56, Val loss: 10.51, Val acc: 0.58
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.38, min-max: 0.00-2.00]
# Epoch 7
# -------------------------------
# Train loss: 147.54, Val loss: 10.86, Val acc: 0.53
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.28, min-max: 0.00-2.00]
# Epoch 8
# -------------------------------
# Train loss: 143.59, Val loss: 11.26, Val acc: 0.57
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.29, min-max: 0.00-2.00]
# Epoch 9
# -------------------------------
# Train loss: 141.77, Val loss: 10.73, Val acc: 0.51
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.37, min-max: 0.00-2.00]
# Epoch 10
# -------------------------------
# Train loss: 137.99, Val loss: 11.00, Val acc: 0.46
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.67, min-max: 0.00-3.00]
# Epoch 11
# -------------------------------
# Train loss: 133.63, Val loss: 10.93, Val acc: 0.60
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.47, min-max: 0.00-3.00]
# Epoch 12
# -------------------------------
# Train loss: 127.81, Val loss: 11.13, Val acc: 0.56
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.33, min-max: 0.00-3.00]
# Epoch 13
# -------------------------------
# Train loss: 127.15, Val loss: 12.31, Val acc: 0.52
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.39, min-max: 0.00-3.00]
# Epoch 14
# -------------------------------
# Train loss: 121.43, Val loss: 10.64, Val acc: 0.56
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.60, min-max: 0.00-3.00]
# Epoch 15
# -------------------------------
# Train loss: 145.32, Val loss: 10.66, Val acc: 0.50
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.23, min-max: 1.00-3.00]
# Epoch 16
# -------------------------------
# Train loss: 139.19, Val loss: 11.76, Val acc: 0.44
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.52, min-max: 0.00-3.00]
# Epoch 17
# -------------------------------
# Train loss: 127.74, Val loss: 11.51, Val acc: 0.60
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.37, min-max: 0.00-2.00]
# Epoch 18
# -------------------------------
# Train loss: 120.03, Val loss: 11.43, Val acc: 0.52
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.60, min-max: 0.00-2.00]
# Epoch 19
# -------------------------------
# Train loss: 123.74, Val loss: 12.07, Val acc: 0.51
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.70, min-max: 0.00-3.00]
# Epoch 20
# -------------------------------
# Train loss: 121.92, Val loss: 12.64, Val acc: 0.59
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.26, min-max: 0.00-2.00]
# Epoch 21
# -------------------------------
# Train loss: 144.98, Val loss: 12.65, Val acc: 0.48
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.54, min-max: 0.00-2.00]
# Epoch 22
# -------------------------------
# Train loss: 128.41, Val loss: 13.38, Val acc: 0.50
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.77, min-max: 0.00-3.00]
# Epoch 23
# -------------------------------
# Train loss: 117.45, Val loss: 10.74, Val acc: 0.56
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.38, min-max: 0.00-3.00]
# Epoch 24
# -------------------------------
# Train loss: 111.52, Val loss: 12.94, Val acc: 0.52
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.57, min-max: 0.00-2.00]
# Epoch 25
# -------------------------------
# Train loss: 113.41, Val loss: 12.21, Val acc: 0.50
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.32, min-max: 0.00-2.00]
# Epoch 26
# -------------------------------
# Train loss: 110.73, Val loss: 11.10, Val acc: 0.56
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.54, min-max: 0.00-3.00]
# Epoch 27
# -------------------------------
# Train loss: 99.12, Val loss: 11.86, Val acc: 0.58
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.73, min-max: 0.00-3.00]
# Epoch 28
# -------------------------------
# Train loss: 95.30, Val loss: 11.96, Val acc: 0.59
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.73, min-max: 0.00-3.00]
# Epoch 29
# -------------------------------
# Train loss: 99.15, Val loss: 21.07, Val acc: 0.33
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.44, min-max: 0.00-3.00]
# Epoch 30
# -------------------------------
# Train loss: 119.20, Val loss: 12.15, Val acc: 0.52
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.60, min-max: 0.00-3.00]
# Epoch 31
# -------------------------------
# Train loss: 98.20, Val loss: 11.50, Val acc: 0.63
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.63, min-max: 0.00-3.00]
# Epoch 32
# -------------------------------
# Train loss: 94.22, Val loss: 11.43, Val acc: 0.51
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.68, min-max: 0.00-3.00]
# Epoch 33
# -------------------------------
# Train loss: 91.53, Val loss: 11.48, Val acc: 0.56
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.51, min-max: 0.00-3.00]
# Epoch 34
# -------------------------------
# Train loss: 84.25, Val loss: 12.33, Val acc: 0.48
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.64, min-max: 0.00-3.00]
# Epoch 35
# -------------------------------
# Train loss: 83.63, Val loss: 11.84, Val acc: 0.62
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.65, min-max: 0.00-3.00]
# Epoch 36
# -------------------------------
# Train loss: 85.85, Val loss: 13.96, Val acc: 0.42
# Best Epoch: 4 (Val loss: 10.35)
# [val var: 0.86, min-max: 0.00-3.00]
# Epoch 37
# -------------------------------
# Train loss: 82.83, Val loss: 10.04, Val acc: 0.67
# Best Epoch: 37 (Val loss: 10.04)
# [val var: 0.64, min-max: 0.00-3.00]
# Epoch 38
# -------------------------------
# Train loss: 79.61, Val loss: 11.19, Val acc: 0.56
# Best Epoch: 37 (Val loss: 10.04)
# [val var: 0.75, min-max: 0.00-3.00]
# Epoch 39
# -------------------------------
# Train loss: 76.88, Val loss: 9.40, Val acc: 0.66
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.48, min-max: 0.00-3.00]
# Epoch 40
# -------------------------------
# Train loss: 67.48, Val loss: 13.50, Val acc: 0.64
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.64, min-max: 0.00-3.00]
# Epoch 41
# -------------------------------
# Train loss: 67.38, Val loss: 11.46, Val acc: 0.56
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.63, min-max: 0.00-3.00]
# Epoch 42
# -------------------------------
# Train loss: 66.79, Val loss: 9.53, Val acc: 0.59
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.76, min-max: 0.00-3.00]
# Epoch 43
# -------------------------------
# Train loss: 78.53, Val loss: 11.19, Val acc: 0.50
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.54, min-max: 0.00-2.00]
# Epoch 44
# -------------------------------
# Train loss: 95.11, Val loss: 9.92, Val acc: 0.62
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.43, min-max: 0.00-3.00]
# Epoch 45
# -------------------------------
# Train loss: 79.35, Val loss: 11.23, Val acc: 0.59
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.72, min-max: 0.00-3.00]
# Epoch 46
# -------------------------------
# Train loss: 72.47, Val loss: 11.77, Val acc: 0.61
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.55, min-max: 0.00-2.00]
# Epoch 47
# -------------------------------
# Train loss: 76.01, Val loss: 13.40, Val acc: 0.51
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.55, min-max: 0.00-2.00]
# Epoch 48
# -------------------------------
# Train loss: 62.56, Val loss: 12.84, Val acc: 0.65
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.67, min-max: 0.00-3.00]
# Epoch 49
# -------------------------------
# Train loss: 71.47, Val loss: 13.04, Val acc: 0.59
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.58, min-max: 0.00-3.00]
# Epoch 50
# -------------------------------
# Train loss: 70.85, Val loss: 13.96, Val acc: 0.52
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.64, min-max: 0.00-2.00]
# Epoch 51
# -------------------------------
# Train loss: 127.99, Val loss: 11.21, Val acc: 0.44
# Best Epoch: 39 (Val loss: 9.40)
# [val var: 0.19, min-max: 1.00-3.00]
# Epoch 52
# -------------------------------
# Max patience reached, now loading the best checkpoint...
# Exiting...

# %% [markdown]
# # Eval

# %%
pd.DataFrame({"train": train_losses, "val": [float(v) for v in val_losses]}, index=range(len(train_losses))).plot()
# Out:
# <Axes: >

# %%
test_loader = DataLoader(ImageDataset(pll_test, transform=rs_transform), batch_size=1)
predictions, labels, loss, acc = validate_clf(model, test_loader)
print(f'Acc: {acc:.2f}')
print(classification_report(labels, predictions))
ax = ConfusionMatrixDisplay.from_predictions(labels, predictions);
ax.figure_.savefig('confusion.pdf', format='PDF', dpi=300)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Acc: 0.67
#               precision    recall  f1-score   support
#
#            0       0.25      0.12      0.17         8
#            1       0.66      0.70      0.68        44
#            2       0.69      0.73      0.71        48
#            3       1.00      0.60      0.75         5
#
#     accuracy                           0.67       105
#    macro avg       0.65      0.54      0.58       105
# weighted avg       0.66      0.67      0.66       105

# %% [markdown]
# # Saliency

# %%
# !rm -R heatmaps
# !mkdir heatmaps
dataloader = DataLoader(ImageDataset(pll_test, transform=rs_transform), batch_size=1)
device = 'cpu'
criterion = nn.CrossEntropyLoss().to(device)
model.eval()
for batch_index, (batch, labels) in enumerate(dataloader):
    batch = batch.to(device)
    labels = labels.to(device)
    batch = batch.requires_grad_(requires_grad=True)

    output = model(batch).to(device)
    loss = criterion(output, labels)

    loss.backward()

    batch_grad = batch.grad.cpu().detach().numpy()
    batch_grad = np.squeeze(batch_grad)
    batch_grad = np.absolute(batch_grad)

    fig, axs = plt.subplots(2, 1, figsize=(10, 5))
    axs[0].imshow(batch_grad, cmap='hot', interpolation='nearest')
    axs[1].imshow(np.squeeze(batch.cpu().detach().numpy()), cmap='gray')

    # plt.colorbar()
    plt.savefig(f'./heatmaps/heatmap_{batch_index:d}-DATE:{pll.iloc[batch_index].date}-PRED:{np.argmax(output.detach(), 1)}')
    plt.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Ablation

# %%
dataloader = DataLoader(ImageDataset(pll_test.iloc[:batch_size], transform=white_fragment_ablation), batch_size=1)
device = 'cpu'
criterion = nn.CrossEntropyLoss().to(device)
model.eval()
for batch_index, (batch, labels) in enumerate(dataloader):
    batch = batch.to(device)
    labels = labels.to(device)
    batch = batch.requires_grad_(requires_grad=True)

    output = model(batch).to(device)
    loss = criterion(output, labels)

    loss.backward()

    batch_grad = batch.grad.cpu().detach().numpy()
    batch_grad = np.squeeze(batch_grad)
    batch_grad = np.absolute(batch_grad)

    fig, axs = plt.subplots(2, 1, figsize=(10, 5))
    axs[0].imshow(batch_grad, cmap='hot', interpolation='nearest')
    axs[1].imshow(np.squeeze(batch.cpu().detach().numpy()), cmap='gray')

    plt.show()
    plt.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
