# %% [markdown]
# <a href="https://colab.research.google.com/github/ipavlopoulos/palit/blob/main/code/fcnnr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Source code
#!git clone https://github.com/ipavlopoulos/palit.git
#from palit.code.regression import *
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset, TensorDataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import skimage
from skimage import transform
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import *
from sklearn.model_selection import GroupShuffleSplit, train_test_split
from sklearn.metrics import confusion_matrix
import xgboost as xgb

from tqdm.notebook import tqdm
import os
import random
class FCNNR(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, 5, stride=1, padding=0)
        self.norm1 =  nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.norm2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(41472, 1024, bias=True) # 108928 if the 2nd ConvNet is active
        self.norm3 = nn.BatchNorm1d(1024)
        self.fc2 = nn.Linear(1024, 512, bias=True)
        self.norm4 = nn.BatchNorm1d(512)
        self.dropout = nn.Dropout(0.1)
        self.fc3 = nn.Linear(512, 1, bias=True) # regression output

    def forward(self, x):
        x = self.pool(self.norm1(F.relu(self.conv1(x.unsqueeze(1)))))
        x = self.pool(self.norm2(F.relu(self.conv2(x))))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.norm3(F.relu(self.fc1(x))) # could add self.norm3
        x = self.norm4(F.relu(self.fc2(x))) # could add self.norm4
        x = self.dropout(x) # our augmentation is competitive to dropout at the input (yet locally coherent)
        x = self.fc3(x)
        return x

# the model predicts the average - high variance
def validate(model, dataloader, device="cpu"):
    predictions, gold_labels = [], []
    with torch.no_grad():
        for id_batch, (inputs, labels) in enumerate(dataloader):
            inputs, labels = inputs.to(device), labels.to(device)
            model.eval()
            model.to(device)
            outputs = model(inputs)
            predictions.extend(outputs.cpu().numpy()[:, 0])
            gold_labels.extend(labels.cpu())
    return predictions, gold_labels

def train(model, dataloader, optimizer, criterion, val_dataloader=None, patience=3, val_metric = mean_absolute_error, n_print=10, N_EPOCHS=4, device="cpu"):
    losses, mae_losses, val_losses, train_losses = [], [], [], []
    dataset_size = len(dataloader.dataset)
    lowest_error = 100000
    best_epoch = -1
    for epoch in range(N_EPOCHS):
        print(f"Epoch {epoch + 1}\n-------------------------------")

        # Loop over batches in an epoch using DataLoader
        for id_batch, (inputs, labels) in enumerate(dataloader):
            model.train()
            inputs, labels = inputs.to(device), labels.float().flatten().to(device)
            outputs = model(inputs).flatten()
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Print the loss for this batch (every n batches, plus the # examples)
            if id_batch % n_print == 0:
                loss, current = loss.item(), (id_batch + 1) * len(inputs)
                losses.append(loss)
                mae = nn.L1Loss()
                mae_loss = mae(outputs, labels)
                mae_losses.append(mae_loss)
                print(f"loss: {loss:.2f} (@all: {np.mean(losses):.2f}) mae: {mae_loss:.2f}  [{current:>2d}/{dataset_size:>2d}]")

        if val_dataloader is not None:
            if (patience>0) and (epoch-best_epoch>patience-1):
                print("Max patience reached, now loading the best checkpoint...")
                model.load_state_dict(torch.load("checkpoint.pt"))
                print("Exiting...")
                break
            predictions, labels = validate(model, val_dataloader, device=device)
            val_error = val_metric(labels, predictions)
            train_predictions, train_labels = validate(model, dataloader, device=device)
            train_error = val_metric(train_predictions, train_labels)
            val_losses.append(val_error)
            train_losses.append(train_error)
            if (patience>0) and (val_error<lowest_error):
                lowest_error = val_error
                best_epoch = epoch
                torch.save(model.state_dict(), "checkpoint.pt")
            print(f"Train loss: {train_error:.2f}, Val loss: {val_error:.2f}, Best Epoch: {best_epoch+1} (Val loss: {lowest_error:.2f}) [val var: {np.var(predictions):.2f}, min-max: {min(predictions):.2f}-{max(predictions):.2f}]")
    return losses, mae_losses, train_losses, val_losses

class ImageDataset(TensorDataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return self.dataframe.shape[0]

    def __getitem__(self, idx):
        sample, date = self.dataframe.iloc[idx].img.astype(np.float32), self.dataframe.iloc[idx].date
        if self.transform is not None:
            sample = self.transform(sample)
            sample = sample.reshape(sample.shape[1], sample.shape[2]) # grayscale
        return sample, date # 1CE-4CE


augment = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomAffine(3), # turn
    transforms.RandomResizedCrop((50, 300), scale=(0.75, 1.0), ratio=(1, 6)), # crop n scale (add scale to control this)
    #transforms.RandomCrop((30, 30)),
    transforms.GaussianBlur(3), # blur
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.5, value=0.5), # erase
])

cc_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.CenterCrop((50, 300)),
    transforms.ToTensor(),
])

rs_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((50,300)),
    transforms.ToTensor(),
])

# %% [markdown]
# # Data loading

# %%
# %%capture
# ACTION needed: download the data (with gdown or re-create using PaLit.xlsx)
pll = pd.read_pickle("pll.csv")

# %%
dataset = pll.explode("img")
dataset = dataset[dataset.img.notna()]
print("Lines num:", dataset.shape[0])
# Out:
# Lines num: 4717

# %%
img_data = pd.DataFrame(dataset.img.apply(lambda x: x.shape).tolist(), index=dataset.index, columns=["H", "W"])
img_data['date'] = dataset.date
sns.kdeplot(data=img_data, x='W', y='H', hue='date')
sns.rugplot(data=img_data, x="W", y="H", lw=1, alpha=.005);

# %%
sns.scatterplot(data=img_data, x='W', y='H', hue='date')
sns.rugplot(data=img_data, x="W", y="H", lw=1, alpha=.005);

# %%
w,h = 300,50
dataset = dataset[(img_data.W>w)&(img_data.H>h)]
dataset.insert(0, "lid", range(1, dataset.shape[0]+1))

# %%
# Data split with non-exclusive fragments between train, val, test
pll_train, pll_test = train_test_split(dataset, test_size=0.1, random_state=2023)
pll_train, pll_val = train_test_split(pll_train, test_size=pll_test.shape[0], random_state=2023)

print(pll_train.shape[0], pll_val.shape[0], pll_test.shape[0])
pd.DataFrame({"train": pll_train.date.value_counts(),
              "dev": pll_val.date.value_counts(),
              "test":pll_test.date.value_counts()}).plot.pie(subplots=True, autopct=f'%.1f', legend=False);
# Out:
# 2218 278 278

# %% [markdown]
# # Training

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
fcnn = Net().to(device)
f1_loss = lambda g,p: 1-f1_score([int(i) for i in g],[int(i) for i in p], zero_division=0, average='macro')
mse_loss, mae_loss, train_losses, val_losses = train(fcnn,
                                                     DataLoader(ImageDataset(pll_train, transform=augment), batch_size=32, shuffle=True, drop_last=False),
                                                     optimizer=optim.Adam(fcnn.parameters(), lr=1e-5, weight_decay=1e-5),
                                                     criterion=nn.MSELoss(), #nn.SmoothL1Loss(),
                                                     N_EPOCHS=200,
                                                     device=device,
                                                     val_metric= mean_squared_error, # alt: 1-F1(rounded, macro)
                                                     patience=20,
                                                     val_dataloader=DataLoader(ImageDataset(pll_val, transform=cc_transform), batch_size=1, drop_last=False)
                                                     )

torch.save(fcnn.state_dict(), "checkpoint.pt")
print(f"Parameters: {nn.utils.parameters_to_vector(fcnn.parameters()).numel():.1f}")
fcnn.eval()
pd.DataFrame({"train": train_losses, "val": [float(v) for v in val_losses]}, index=range(len(train_losses))).plot();
# Out:
# Epoch 1
# -------------------------------
# loss: 5.45 (@all: 5.45) mae: 2.06  [32/2218]
# loss: 5.90 (@all: 5.68) mae: 2.28  [352/2218]
# loss: 7.25 (@all: 6.20) mae: 2.52  [672/2218]
# loss: 6.22 (@all: 6.21) mae: 2.34  [992/2218]
# loss: 6.29 (@all: 6.22) mae: 2.38  [1312/2218]
# loss: 6.04 (@all: 6.19) mae: 2.23  [1632/2218]
# loss: 5.84 (@all: 6.14) mae: 2.25  [1952/2218]
# Train loss: 5.57, Val loss: 5.62, Best Epoch: 1 (Val loss: 5.62) [val var: 0.93, min-max: 0.05-4.28]
# Epoch 2
# -------------------------------
# loss: 6.36 (@all: 6.17) mae: 2.21  [32/2218]
# loss: 6.95 (@all: 6.26) mae: 2.53  [352/2218]
# loss: 6.04 (@all: 6.24) mae: 2.30  [672/2218]
# loss: 5.15 (@all: 6.14) mae: 2.09  [992/2218]
# loss: 5.93 (@all: 6.12) mae: 2.24  [1312/2218]
# loss: 6.49 (@all: 6.15) mae: 2.44  [1632/2218]
# loss: 6.17 (@all: 6.15) mae: 2.31  [1952/2218]
# Train loss: 5.38, Val loss: 5.37, Best Epoch: 2 (Val loss: 5.37) [val var: 0.11, min-max: -0.07-2.29]
# Epoch 3
# -------------------------------
# loss: 5.25 (@all: 6.09) mae: 2.14  [32/2218]
# loss: 4.71 (@all: 6.00) mae: 1.99  [352/2218]
# loss: 6.15 (@all: 6.01) mae: 2.22  [672/2218]
# loss: 6.58 (@all: 6.04) mae: 2.37  [992/2218]
# loss: 5.16 (@all: 6.00) mae: 2.12  [1312/2218]
# loss: 4.60 (@all: 5.93) mae: 2.02  [1632/2218]
# loss: 4.33 (@all: 5.85) mae: 1.88  [1952/2218]
# Train loss: 4.16, Val loss: 4.14, Best Epoch: 3 (Val loss: 4.14) [val var: 0.42, min-max: 0.39-4.62]
# Epoch 4
# -------------------------------
# loss: 3.73 (@all: 5.75) mae: 1.77  [32/2218]
# loss: 4.02 (@all: 5.68) mae: 1.80  [352/2218]
# loss: 4.52 (@all: 5.63) mae: 1.93  [672/2218]
# loss: 3.26 (@all: 5.54) mae: 1.54  [992/2218]
# loss: 3.72 (@all: 5.47) mae: 1.72  [1312/2218]
# loss: 3.49 (@all: 5.39) mae: 1.69  [1632/2218]
# loss: 1.72 (@all: 5.26) mae: 1.14  [1952/2218]
# Train loss: 2.31, Val loss: 2.22, Best Epoch: 4 (Val loss: 2.22) [val var: 0.20, min-max: 0.78-4.47]
# Epoch 5
# -------------------------------
# loss: 2.07 (@all: 5.15) mae: 1.21  [32/2218]
# loss: 1.87 (@all: 5.04) mae: 1.15  [352/2218]
# loss: 1.75 (@all: 4.94) mae: 1.19  [672/2218]
# loss: 1.38 (@all: 4.83) mae: 1.04  [992/2218]
# loss: 2.08 (@all: 4.74) mae: 1.25  [1312/2218]
# loss: 1.27 (@all: 4.64) mae: 0.91  [1632/2218]
# loss: 1.46 (@all: 4.55) mae: 1.03  [1952/2218]
# Train loss: 1.01, Val loss: 0.92, Best Epoch: 5 (Val loss: 0.92) [val var: 0.12, min-max: 0.53-3.96]
# Epoch 6
# -------------------------------
# loss: 1.15 (@all: 4.45) mae: 0.87  [32/2218]
# loss: 1.13 (@all: 4.36) mae: 0.78  [352/2218]
# loss: 0.87 (@all: 4.27) mae: 0.73  [672/2218]
# loss: 1.08 (@all: 4.19) mae: 0.92  [992/2218]
# loss: 0.72 (@all: 4.10) mae: 0.64  [1312/2218]
# loss: 1.42 (@all: 4.04) mae: 0.89  [1632/2218]
# loss: 0.77 (@all: 3.96) mae: 0.64  [1952/2218]
# Train loss: 0.73, Val loss: 0.72, Best Epoch: 6 (Val loss: 0.72) [val var: 0.11, min-max: 1.33-5.52]
# Epoch 7
# -------------------------------
# loss: 0.91 (@all: 3.89) mae: 0.81  [32/2218]
# loss: 0.69 (@all: 3.82) mae: 0.63  [352/2218]
# loss: 1.15 (@all: 3.76) mae: 0.91  [672/2218]
# loss: 1.09 (@all: 3.70) mae: 0.91  [992/2218]
# loss: 0.89 (@all: 3.64) mae: 0.80  [1312/2218]
# loss: 1.18 (@all: 3.59) mae: 0.91  [1632/2218]
# loss: 0.81 (@all: 3.53) mae: 0.74  [1952/2218]
# Train loss: 0.70, Val loss: 0.66, Best Epoch: 7 (Val loss: 0.66) [val var: 0.12, min-max: 1.07-3.36]
# Epoch 8
# -------------------------------
# loss: 0.89 (@all: 3.48) mae: 0.81  [32/2218]
# loss: 0.86 (@all: 3.43) mae: 0.74  [352/2218]
# loss: 0.72 (@all: 3.38) mae: 0.70  [672/2218]
# loss: 0.41 (@all: 3.32) mae: 0.55  [992/2218]
# loss: 0.82 (@all: 3.27) mae: 0.76  [1312/2218]
# loss: 0.67 (@all: 3.23) mae: 0.68  [1632/2218]
# loss: 0.85 (@all: 3.18) mae: 0.75  [1952/2218]
# Train loss: 0.70, Val loss: 0.77, Best Epoch: 7 (Val loss: 0.66) [val var: 0.14, min-max: 1.59-5.56]
# Epoch 9
# -------------------------------
# loss: 0.60 (@all: 3.14) mae: 0.63  [32/2218]
# loss: 0.86 (@all: 3.10) mae: 0.79  [352/2218]
# loss: 0.64 (@all: 3.06) mae: 0.63  [672/2218]
# loss: 0.60 (@all: 3.02) mae: 0.62  [992/2218]
# loss: 0.75 (@all: 2.98) mae: 0.72  [1312/2218]
# loss: 0.62 (@all: 2.94) mae: 0.63  [1632/2218]
# loss: 0.73 (@all: 2.91) mae: 0.70  [1952/2218]
# Train loss: 0.69, Val loss: 0.73, Best Epoch: 7 (Val loss: 0.66) [val var: 0.10, min-max: 1.82-4.94]
# Epoch 10
# -------------------------------
# loss: 0.67 (@all: 2.87) mae: 0.66  [32/2218]
# loss: 0.38 (@all: 2.83) mae: 0.53  [352/2218]
# loss: 0.73 (@all: 2.80) mae: 0.73  [672/2218]
# loss: 0.73 (@all: 2.77) mae: 0.66  [992/2218]
# loss: 0.72 (@all: 2.74) mae: 0.71  [1312/2218]
# loss: 0.59 (@all: 2.71) mae: 0.62  [1632/2218]
# loss: 0.84 (@all: 2.68) mae: 0.74  [1952/2218]
# Train loss: 0.66, Val loss: 0.67, Best Epoch: 7 (Val loss: 0.66) [val var: 0.13, min-max: 0.98-4.20]
# Epoch 11
# -------------------------------
# loss: 0.51 (@all: 2.65) mae: 0.58  [32/2218]
# loss: 0.71 (@all: 2.63) mae: 0.70  [352/2218]
# loss: 0.90 (@all: 2.60) mae: 0.79  [672/2218]
# loss: 0.63 (@all: 2.57) mae: 0.64  [992/2218]
# loss: 0.63 (@all: 2.55) mae: 0.66  [1312/2218]
# loss: 0.71 (@all: 2.52) mae: 0.68  [1632/2218]
# loss: 1.07 (@all: 2.51) mae: 0.90  [1952/2218]
# Train loss: 0.66, Val loss: 0.71, Best Epoch: 7 (Val loss: 0.66) [val var: 0.09, min-max: 1.43-4.38]
# Epoch 12
# -------------------------------
# loss: 0.58 (@all: 2.48) mae: 0.61  [32/2218]
# loss: 0.85 (@all: 2.46) mae: 0.73  [352/2218]
# loss: 0.63 (@all: 2.44) mae: 0.67  [672/2218]
# loss: 0.73 (@all: 2.42) mae: 0.73  [992/2218]
# loss: 0.55 (@all: 2.39) mae: 0.62  [1312/2218]
# loss: 0.89 (@all: 2.38) mae: 0.78  [1632/2218]
# loss: 0.59 (@all: 2.35) mae: 0.62  [1952/2218]
# Train loss: 0.65, Val loss: 0.64, Best Epoch: 12 (Val loss: 0.64) [val var: 0.11, min-max: 1.05-3.68]
# Epoch 13
# -------------------------------
# loss: 0.75 (@all: 2.34) mae: 0.70  [32/2218]
# loss: 0.28 (@all: 2.31) mae: 0.48  [352/2218]
# loss: 0.44 (@all: 2.29) mae: 0.58  [672/2218]
# loss: 0.65 (@all: 2.27) mae: 0.65  [992/2218]
# loss: 0.78 (@all: 2.25) mae: 0.71  [1312/2218]
# loss: 0.79 (@all: 2.24) mae: 0.73  [1632/2218]
# loss: 0.86 (@all: 2.22) mae: 0.77  [1952/2218]
# Train loss: 0.65, Val loss: 0.70, Best Epoch: 12 (Val loss: 0.64) [val var: 0.09, min-max: 1.55-4.71]
# Epoch 14
# -------------------------------
# loss: 0.59 (@all: 2.21) mae: 0.64  [32/2218]
# loss: 0.55 (@all: 2.19) mae: 0.61  [352/2218]
# loss: 0.73 (@all: 2.17) mae: 0.73  [672/2218]
# loss: 0.69 (@all: 2.16) mae: 0.66  [992/2218]
# loss: 0.64 (@all: 2.14) mae: 0.63  [1312/2218]
# loss: 0.74 (@all: 2.13) mae: 0.74  [1632/2218]
# loss: 0.77 (@all: 2.11) mae: 0.73  [1952/2218]
# Train loss: 0.66, Val loss: 0.66, Best Epoch: 12 (Val loss: 0.64) [val var: 0.17, min-max: 0.80-3.56]
# Epoch 15
# -------------------------------
# loss: 0.51 (@all: 2.10) mae: 0.59  [32/2218]
# loss: 0.75 (@all: 2.08) mae: 0.74  [352/2218]
# loss: 0.55 (@all: 2.07) mae: 0.60  [672/2218]
# loss: 0.56 (@all: 2.05) mae: 0.61  [992/2218]
# loss: 0.59 (@all: 2.04) mae: 0.63  [1312/2218]
# loss: 0.68 (@all: 2.03) mae: 0.66  [1632/2218]
# loss: 0.73 (@all: 2.01) mae: 0.71  [1952/2218]
# Train loss: 0.67, Val loss: 0.68, Best Epoch: 12 (Val loss: 0.64) [val var: 0.20, min-max: 0.29-3.04]
# Epoch 16
# -------------------------------
# loss: 0.60 (@all: 2.00) mae: 0.67  [32/2218]
# loss: 0.65 (@all: 1.99) mae: 0.68  [352/2218]
# loss: 0.58 (@all: 1.97) mae: 0.65  [672/2218]
# loss: 0.61 (@all: 1.96) mae: 0.62  [992/2218]
# loss: 0.66 (@all: 1.95) mae: 0.68  [1312/2218]
# loss: 0.64 (@all: 1.94) mae: 0.69  [1632/2218]
# loss: 0.69 (@all: 1.93) mae: 0.68  [1952/2218]
# Train loss: 0.65, Val loss: 0.65, Best Epoch: 12 (Val loss: 0.64) [val var: 0.15, min-max: 0.60-3.21]
# Epoch 17
# -------------------------------
# loss: 0.61 (@all: 1.92) mae: 0.65  [32/2218]
# loss: 0.45 (@all: 1.90) mae: 0.56  [352/2218]
# loss: 0.58 (@all: 1.89) mae: 0.65  [672/2218]
# loss: 0.48 (@all: 1.88) mae: 0.52  [992/2218]
# loss: 0.52 (@all: 1.87) mae: 0.61  [1312/2218]
# loss: 0.69 (@all: 1.86) mae: 0.69  [1632/2218]
# loss: 0.72 (@all: 1.85) mae: 0.69  [1952/2218]
# Train loss: 0.72, Val loss: 0.72, Best Epoch: 12 (Val loss: 0.64) [val var: 0.27, min-max: 0.25-3.03]
# Epoch 18
# -------------------------------
# loss: 0.71 (@all: 1.84) mae: 0.71  [32/2218]
# loss: 1.18 (@all: 1.83) mae: 0.95  [352/2218]
# loss: 0.39 (@all: 1.82) mae: 0.54  [672/2218]
# loss: 0.75 (@all: 1.81) mae: 0.75  [992/2218]
# loss: 0.92 (@all: 1.81) mae: 0.82  [1312/2218]
# loss: 0.74 (@all: 1.80) mae: 0.70  [1632/2218]
# loss: 0.56 (@all: 1.79) mae: 0.60  [1952/2218]
# Train loss: 0.63, Val loss: 0.65, Best Epoch: 12 (Val loss: 0.64) [val var: 0.09, min-max: 1.17-4.16]
# Epoch 19
# -------------------------------
# loss: 0.49 (@all: 1.78) mae: 0.55  [32/2218]
# loss: 0.56 (@all: 1.77) mae: 0.61  [352/2218]
# loss: 0.67 (@all: 1.76) mae: 0.65  [672/2218]
# loss: 0.98 (@all: 1.75) mae: 0.85  [992/2218]
# loss: 0.47 (@all: 1.74) mae: 0.59  [1312/2218]
# loss: 0.72 (@all: 1.74) mae: 0.72  [1632/2218]
# loss: 0.76 (@all: 1.73) mae: 0.70  [1952/2218]
# Train loss: 0.63, Val loss: 0.69, Best Epoch: 12 (Val loss: 0.64) [val var: 0.09, min-max: 1.38-4.99]
# Epoch 20
# -------------------------------
# loss: 0.63 (@all: 1.72) mae: 0.62  [32/2218]
# loss: 0.63 (@all: 1.71) mae: 0.69  [352/2218]
# loss: 0.65 (@all: 1.70) mae: 0.64  [672/2218]
# loss: 0.44 (@all: 1.69) mae: 0.57  [992/2218]
# loss: 0.52 (@all: 1.69) mae: 0.58  [1312/2218]
# loss: 0.59 (@all: 1.68) mae: 0.65  [1632/2218]
# loss: 0.66 (@all: 1.67) mae: 0.66  [1952/2218]
# Train loss: 0.63, Val loss: 0.65, Best Epoch: 12 (Val loss: 0.64) [val var: 0.12, min-max: 0.83-4.09]
# Epoch 21
# -------------------------------
# loss: 0.54 (@all: 1.66) mae: 0.61  [32/2218]
# loss: 0.22 (@all: 1.65) mae: 0.44  [352/2218]
# loss: 0.77 (@all: 1.65) mae: 0.74  [672/2218]
# loss: 0.53 (@all: 1.64) mae: 0.62  [992/2218]
# loss: 0.55 (@all: 1.63) mae: 0.63  [1312/2218]
# loss: 0.62 (@all: 1.62) mae: 0.66  [1632/2218]
# loss: 0.63 (@all: 1.62) mae: 0.63  [1952/2218]
# Train loss: 0.65, Val loss: 0.66, Best Epoch: 12 (Val loss: 0.64) [val var: 0.17, min-max: 0.50-3.46]
# Epoch 22
# -------------------------------
# loss: 0.70 (@all: 1.61) mae: 0.71  [32/2218]
# loss: 0.43 (@all: 1.60) mae: 0.53  [352/2218]
# loss: 0.83 (@all: 1.60) mae: 0.76  [672/2218]
# loss: 0.93 (@all: 1.59) mae: 0.82  [992/2218]
# loss: 0.80 (@all: 1.59) mae: 0.75  [1312/2218]
# loss: 0.72 (@all: 1.58) mae: 0.71  [1632/2218]
# loss: 0.39 (@all: 1.58) mae: 0.53  [1952/2218]
# Train loss: 0.64, Val loss: 0.69, Best Epoch: 12 (Val loss: 0.64) [val var: 0.08, min-max: 1.53-4.54]
# Epoch 23
# -------------------------------
# loss: 0.43 (@all: 1.57) mae: 0.57  [32/2218]
# loss: 0.58 (@all: 1.56) mae: 0.61  [352/2218]
# loss: 0.60 (@all: 1.56) mae: 0.64  [672/2218]
# loss: 0.70 (@all: 1.55) mae: 0.70  [992/2218]
# loss: 0.84 (@all: 1.55) mae: 0.75  [1312/2218]
# loss: 0.46 (@all: 1.54) mae: 0.55  [1632/2218]
# loss: 0.50 (@all: 1.53) mae: 0.60  [1952/2218]
# loss: 0.58 (@all: 1.36) mae: 0.63  [1952/2218]
# Train loss: 0.62, Val loss: 0.62, Best Epoch: 28 (Val loss: 0.62) [val var: 0.13, min-max: 0.70-3.59]
# Epoch 29
# -------------------------------
# loss: 0.51 (@all: 1.36) mae: 0.62  [32/2218]
# loss: 0.55 (@all: 1.36) mae: 0.60  [352/2218]
# loss: 0.41 (@all: 1.35) mae: 0.53  [672/2218]
# loss: 0.43 (@all: 1.35) mae: 0.54  [992/2218]
# loss: 0.78 (@all: 1.34) mae: 0.74  [1312/2218]
# loss: 0.56 (@all: 1.34) mae: 0.63  [1632/2218]
# loss: 0.50 (@all: 1.34) mae: 0.58  [1952/2218]
# Train loss: 0.67, Val loss: 0.75, Best Epoch: 28 (Val loss: 0.62) [val var: 0.11, min-max: 1.63-5.42]
# Epoch 30
# -------------------------------
# loss: 0.45 (@all: 1.33) mae: 0.58  [32/2218]
# loss: 0.49 (@all: 1.33) mae: 0.57  [352/2218]
# loss: 0.79 (@all: 1.32) mae: 0.73  [672/2218]
# loss: 0.67 (@all: 1.32) mae: 0.66  [992/2218]
# loss: 0.62 (@all: 1.32) mae: 0.65  [1312/2218]
# loss: 0.33 (@all: 1.31) mae: 0.50  [1632/2218]
# loss: 0.60 (@all: 1.31) mae: 0.65  [1952/2218]
# Train loss: 0.65, Val loss: 0.65, Best Epoch: 28 (Val loss: 0.62) [val var: 0.20, min-max: 0.34-3.40]
# Epoch 31
# -------------------------------
# loss: 0.37 (@all: 1.31) mae: 0.55  [32/2218]
# loss: 0.63 (@all: 1.30) mae: 0.69  [352/2218]
# loss: 0.89 (@all: 1.30) mae: 0.79  [672/2218]
# loss: 0.79 (@all: 1.30) mae: 0.77  [992/2218]
# loss: 0.55 (@all: 1.29) mae: 0.62  [1312/2218]
# loss: 0.42 (@all: 1.29) mae: 0.57  [1632/2218]
# loss: 0.72 (@all: 1.29) mae: 0.73  [1952/2218]
# Train loss: 0.73, Val loss: 0.75, Best Epoch: 28 (Val loss: 0.62) [val var: 0.34, min-max: -0.10-3.29]
# Epoch 32
# -------------------------------
# loss: 0.71 (@all: 1.29) mae: 0.71  [32/2218]
# loss: 0.58 (@all: 1.28) mae: 0.64  [352/2218]
# loss: 0.45 (@all: 1.28) mae: 0.58  [672/2218]
# loss: 0.67 (@all: 1.28) mae: 0.69  [992/2218]
# loss: 0.46 (@all: 1.27) mae: 0.58  [1312/2218]
# loss: 0.87 (@all: 1.27) mae: 0.79  [1632/2218]
# loss: 0.50 (@all: 1.27) mae: 0.59  [1952/2218]
# Train loss: 0.61, Val loss: 0.62, Best Epoch: 32 (Val loss: 0.62) [val var: 0.11, min-max: 0.80-4.28]
# Epoch 33
# -------------------------------
# loss: 0.70 (@all: 1.26) mae: 0.66  [32/2218]
# loss: 0.33 (@all: 1.26) mae: 0.45  [352/2218]
# loss: 0.64 (@all: 1.26) mae: 0.65  [672/2218]
# loss: 0.49 (@all: 1.25) mae: 0.56  [992/2218]
# loss: 0.60 (@all: 1.25) mae: 0.66  [1312/2218]
# loss: 0.30 (@all: 1.25) mae: 0.50  [1632/2218]
# loss: 0.76 (@all: 1.24) mae: 0.70  [1952/2218]
# Train loss: 0.60, Val loss: 0.64, Best Epoch: 32 (Val loss: 0.62) [val var: 0.08, min-max: 1.28-4.54]
# Epoch 34
# -------------------------------
# loss: 0.83 (@all: 1.24) mae: 0.75  [32/2218]
# loss: 0.78 (@all: 1.24) mae: 0.71  [352/2218]
# loss: 0.50 (@all: 1.24) mae: 0.60  [672/2218]
# loss: 0.47 (@all: 1.23) mae: 0.56  [992/2218]
# loss: 0.57 (@all: 1.23) mae: 0.62  [1312/2218]
# loss: 0.26 (@all: 1.23) mae: 0.46  [1632/2218]
# loss: 0.63 (@all: 1.23) mae: 0.68  [1952/2218]
# Train loss: 0.59, Val loss: 0.60, Best Epoch: 34 (Val loss: 0.60) [val var: 0.08, min-max: 1.07-4.12]
# Epoch 35
# -------------------------------
# loss: 0.46 (@all: 1.22) mae: 0.57  [32/2218]
# loss: 0.59 (@all: 1.22) mae: 0.63  [352/2218]
# loss: 0.47 (@all: 1.22) mae: 0.56  [672/2218]
# loss: 0.50 (@all: 1.21) mae: 0.58  [992/2218]
# loss: 0.59 (@all: 1.21) mae: 0.64  [1312/2218]
# loss: 0.64 (@all: 1.21) mae: 0.66  [1632/2218]
# loss: 0.64 (@all: 1.21) mae: 0.70  [1952/2218]
# Train loss: 0.59, Val loss: 0.61, Best Epoch: 34 (Val loss: 0.60) [val var: 0.09, min-max: 1.08-4.32]
# Epoch 36
# -------------------------------
# loss: 0.33 (@all: 1.20) mae: 0.47  [32/2218]
# loss: 0.62 (@all: 1.20) mae: 0.63  [352/2218]
# loss: 0.57 (@all: 1.20) mae: 0.64  [672/2218]
# loss: 0.46 (@all: 1.19) mae: 0.60  [992/2218]
# loss: 0.75 (@all: 1.19) mae: 0.72  [1312/2218]
# loss: 0.49 (@all: 1.19) mae: 0.58  [1632/2218]
# loss: 0.80 (@all: 1.19) mae: 0.76  [1952/2218]
# Train loss: 0.59, Val loss: 0.62, Best Epoch: 34 (Val loss: 0.60) [val var: 0.10, min-max: 1.17-4.97]
# Epoch 37
# -------------------------------
# loss: 0.66 (@all: 1.19) mae: 0.65  [32/2218]
# loss: 0.50 (@all: 1.18) mae: 0.60  [352/2218]
# loss: 0.64 (@all: 1.18) mae: 0.66  [672/2218]
# loss: 0.53 (@all: 1.18) mae: 0.60  [992/2218]
# loss: 0.81 (@all: 1.18) mae: 0.75  [1312/2218]
# loss: 0.44 (@all: 1.17) mae: 0.58  [1632/2218]
# loss: 0.59 (@all: 1.17) mae: 0.62  [1952/2218]
# Train loss: 0.58, Val loss: 0.60, Best Epoch: 37 (Val loss: 0.60) [val var: 0.12, min-max: 0.95-4.53]
# Epoch 38
# -------------------------------
# loss: 0.36 (@all: 1.17) mae: 0.51  [32/2218]
# loss: 0.70 (@all: 1.17) mae: 0.67  [352/2218]
# loss: 0.68 (@all: 1.17) mae: 0.67  [672/2218]
# loss: 0.53 (@all: 1.16) mae: 0.57  [992/2218]
# loss: 0.75 (@all: 1.16) mae: 0.75  [1312/2218]
# loss: 0.64 (@all: 1.16) mae: 0.66  [1632/2218]
# loss: 0.64 (@all: 1.16) mae: 0.68  [1952/2218]
# Train loss: 0.62, Val loss: 0.62, Best Epoch: 37 (Val loss: 0.60) [val var: 0.18, min-max: 0.67-3.35]
# Epoch 39
# -------------------------------
# loss: 0.37 (@all: 1.15) mae: 0.53  [32/2218]
# loss: 0.51 (@all: 1.15) mae: 0.60  [352/2218]
# loss: 0.65 (@all: 1.15) mae: 0.68  [672/2218]
# loss: 0.28 (@all: 1.15) mae: 0.42  [992/2218]
# loss: 0.40 (@all: 1.14) mae: 0.52  [1312/2218]
# loss: 0.74 (@all: 1.14) mae: 0.72  [1632/2218]
# loss: 0.73 (@all: 1.14) mae: 0.73  [1952/2218]
# Train loss: 0.59, Val loss: 0.59, Best Epoch: 39 (Val loss: 0.59) [val var: 0.14, min-max: 0.94-4.14]
# Epoch 40
# -------------------------------
# loss: 0.76 (@all: 1.14) mae: 0.72  [32/2218]
# loss: 0.61 (@all: 1.14) mae: 0.64  [352/2218]
# loss: 0.54 (@all: 1.14) mae: 0.62  [672/2218]
# loss: 0.60 (@all: 1.13) mae: 0.66  [992/2218]
# loss: 0.50 (@all: 1.13) mae: 0.57  [1312/2218]
# loss: 0.54 (@all: 1.13) mae: 0.63  [1632/2218]
# loss: 0.86 (@all: 1.13) mae: 0.81  [1952/2218]
# Train loss: 0.58, Val loss: 0.60, Best Epoch: 39 (Val loss: 0.59) [val var: 0.14, min-max: 0.80-4.41]
# Epoch 41
# -------------------------------
# loss: 0.71 (@all: 1.13) mae: 0.66  [32/2218]
# loss: 0.67 (@all: 1.13) mae: 0.68  [352/2218]
# loss: 0.69 (@all: 1.12) mae: 0.72  [672/2218]
# loss: 0.44 (@all: 1.12) mae: 0.57  [992/2218]
# loss: 0.57 (@all: 1.12) mae: 0.60  [1312/2218]
# loss: 0.74 (@all: 1.12) mae: 0.70  [1632/2218]
# loss: 0.69 (@all: 1.12) mae: 0.67  [1952/2218]
# Train loss: 0.58, Val loss: 0.58, Best Epoch: 41 (Val loss: 0.58) [val var: 0.12, min-max: 0.94-3.93]
# Epoch 42
# -------------------------------
# loss: 0.53 (@all: 1.12) mae: 0.60  [32/2218]
# loss: 0.51 (@all: 1.11) mae: 0.61  [352/2218]
# loss: 0.69 (@all: 1.11) mae: 0.69  [672/2218]
# loss: 0.67 (@all: 1.11) mae: 0.68  [992/2218]
# loss: 0.52 (@all: 1.11) mae: 0.59  [1312/2218]
# loss: 0.64 (@all: 1.11) mae: 0.66  [1632/2218]
# loss: 0.43 (@all: 1.10) mae: 0.54  [1952/2218]
# Train loss: 0.58, Val loss: 0.62, Best Epoch: 41 (Val loss: 0.58) [val var: 0.10, min-max: 1.36-4.76]
# Epoch 43
# -------------------------------
# loss: 0.69 (@all: 1.10) mae: 0.66  [32/2218]
# loss: 0.57 (@all: 1.10) mae: 0.59  [352/2218]
# loss: 0.80 (@all: 1.10) mae: 0.75  [672/2218]
# loss: 0.44 (@all: 1.10) mae: 0.59  [992/2218]
# loss: 0.48 (@all: 1.10) mae: 0.58  [1312/2218]
# loss: 0.56 (@all: 1.09) mae: 0.64  [1632/2218]
# loss: 0.54 (@all: 1.09) mae: 0.61  [1952/2218]
# Train loss: 0.57, Val loss: 0.59, Best Epoch: 41 (Val loss: 0.58) [val var: 0.11, min-max: 1.28-4.54]
# Epoch 44
# -------------------------------
# loss: 0.71 (@all: 1.09) mae: 0.72  [32/2218]
# loss: 0.65 (@all: 1.09) mae: 0.68  [352/2218]
# loss: 0.58 (@all: 1.09) mae: 0.61  [672/2218]
# loss: 0.58 (@all: 1.09) mae: 0.64  [992/2218]
# loss: 0.69 (@all: 1.08) mae: 0.66  [1312/2218]
# loss: 0.72 (@all: 1.08) mae: 0.72  [1632/2218]
# loss: 0.88 (@all: 1.08) mae: 0.77  [1952/2218]
# Train loss: 0.58, Val loss: 0.63, Best Epoch: 41 (Val loss: 0.58) [val var: 0.10, min-max: 1.63-4.72]
# Epoch 45
# -------------------------------
# loss: 0.73 (@all: 1.08) mae: 0.71  [32/2218]
# loss: 0.80 (@all: 1.08) mae: 0.76  [352/2218]
# loss: 0.61 (@all: 1.08) mae: 0.63  [672/2218]
# loss: 0.40 (@all: 1.08) mae: 0.52  [992/2218]
# loss: 0.55 (@all: 1.08) mae: 0.58  [1312/2218]
# loss: 0.47 (@all: 1.07) mae: 0.56  [1632/2218]
# loss: 0.77 (@all: 1.07) mae: 0.72  [1952/2218]
# Train loss: 0.57, Val loss: 0.57, Best Epoch: 45 (Val loss: 0.57) [val var: 0.14, min-max: 0.86-3.47]
# Epoch 46
# -------------------------------
# loss: 0.48 (@all: 1.07) mae: 0.54  [32/2218]
# loss: 0.51 (@all: 1.07) mae: 0.55  [352/2218]
# loss: 0.62 (@all: 1.07) mae: 0.58  [672/2218]
# loss: 0.54 (@all: 1.07) mae: 0.61  [992/2218]
# loss: 0.51 (@all: 1.06) mae: 0.58  [1312/2218]
# loss: 0.46 (@all: 1.06) mae: 0.58  [1632/2218]
# loss: 0.75 (@all: 1.06) mae: 0.71  [1952/2218]
# Train loss: 0.57, Val loss: 0.59, Best Epoch: 45 (Val loss: 0.57) [val var: 0.10, min-max: 1.33-4.06]
# Epoch 47
# -------------------------------
# loss: 0.33 (@all: 1.06) mae: 0.47  [32/2218]
# loss: 0.59 (@all: 1.06) mae: 0.65  [352/2218]
# loss: 0.58 (@all: 1.06) mae: 0.60  [672/2218]
# loss: 0.46 (@all: 1.05) mae: 0.56  [992/2218]
# loss: 0.54 (@all: 1.05) mae: 0.63  [1312/2218]
# loss: 0.64 (@all: 1.05) mae: 0.71  [1632/2218]
# loss: 0.38 (@all: 1.05) mae: 0.48  [1952/2218]
# Train loss: 0.57, Val loss: 0.59, Best Epoch: 45 (Val loss: 0.57) [val var: 0.12, min-max: 1.31-4.44]
# Epoch 48
# -------------------------------
# loss: 0.46 (@all: 1.05) mae: 0.55  [32/2218]
# loss: 0.50 (@all: 1.05) mae: 0.63  [352/2218]
# loss: 0.74 (@all: 1.04) mae: 0.73  [672/2218]
# loss: 0.85 (@all: 1.04) mae: 0.76  [992/2218]
# loss: 0.76 (@all: 1.04) mae: 0.71  [1312/2218]
# loss: 0.56 (@all: 1.04) mae: 0.63  [1632/2218]
# loss: 0.54 (@all: 1.04) mae: 0.60  [1952/2218]
# Train loss: 0.80, Val loss: 0.90, Best Epoch: 45 (Val loss: 0.57) [val var: 0.62, min-max: -0.34-3.71]
# Epoch 49
# -------------------------------
# loss: 0.79 (@all: 1.04) mae: 0.72  [32/2218]
# loss: 0.76 (@all: 1.04) mae: 0.75  [352/2218]
# loss: 0.54 (@all: 1.04) mae: 0.64  [672/2218]
# loss: 0.49 (@all: 1.04) mae: 0.56  [992/2218]
# loss: 0.24 (@all: 1.03) mae: 0.41  [1312/2218]
# loss: 0.66 (@all: 1.03) mae: 0.63  [1632/2218]
# loss: 0.45 (@all: 1.03) mae: 0.52  [1952/2218]
# Train loss: 0.56, Val loss: 0.57, Best Epoch: 49 (Val loss: 0.57) [val var: 0.13, min-max: 1.36-4.01]
# Epoch 50
# -------------------------------
# loss: 0.64 (@all: 1.03) mae: 0.66  [32/2218]
# loss: 0.56 (@all: 1.03) mae: 0.59  [352/2218]
# loss: 0.49 (@all: 1.03) mae: 0.58  [672/2218]
# loss: 0.54 (@all: 1.03) mae: 0.63  [992/2218]
# loss: 0.40 (@all: 1.02) mae: 0.53  [1312/2218]
# loss: 0.57 (@all: 1.02) mae: 0.64  [1632/2218]
# loss: 0.44 (@all: 1.02) mae: 0.57  [1952/2218]
# Train loss: 0.56, Val loss: 0.56, Best Epoch: 50 (Val loss: 0.56) [val var: 0.14, min-max: 1.25-3.86]
# Epoch 51
# -------------------------------
# loss: 0.60 (@all: 1.02) mae: 0.62  [32/2218]
# loss: 0.62 (@all: 1.02) mae: 0.61  [352/2218]
# loss: 0.61 (@all: 1.02) mae: 0.64  [672/2218]
# loss: 0.52 (@all: 1.02) mae: 0.57  [992/2218]
# loss: 0.44 (@all: 1.01) mae: 0.54  [1312/2218]
# loss: 0.49 (@all: 1.01) mae: 0.60  [1632/2218]
# loss: 0.33 (@all: 1.01) mae: 0.43  [1952/2218]
# Train loss: 0.55, Val loss: 0.57, Best Epoch: 50 (Val loss: 0.56) [val var: 0.12, min-max: 1.53-4.09]
# Epoch 52
# -------------------------------
# loss: 0.52 (@all: 1.01) mae: 0.55  [32/2218]
# loss: 0.49 (@all: 1.01) mae: 0.57  [352/2218]
# loss: 0.42 (@all: 1.01) mae: 0.55  [672/2218]
# loss: 0.80 (@all: 1.01) mae: 0.74  [992/2218]
# loss: 0.63 (@all: 1.00) mae: 0.61  [1312/2218]
# loss: 0.35 (@all: 1.00) mae: 0.50  [1632/2218]
# loss: 0.68 (@all: 1.00) mae: 0.67  [1952/2218]
# Train loss: 0.56, Val loss: 0.59, Best Epoch: 50 (Val loss: 0.56) [val var: 0.13, min-max: 1.57-4.34]
# Epoch 53
# -------------------------------
# loss: 0.71 (@all: 1.00) mae: 0.69  [32/2218]
# loss: 0.53 (@all: 1.00) mae: 0.60  [352/2218]
# loss: 0.33 (@all: 1.00) mae: 0.43  [672/2218]
# loss: 0.58 (@all: 1.00) mae: 0.59  [992/2218]
# loss: 0.53 (@all: 1.00) mae: 0.58  [1312/2218]
# loss: 0.32 (@all: 0.99) mae: 0.47  [1632/2218]
# loss: 0.57 (@all: 0.99) mae: 0.60  [1952/2218]
# Train loss: 0.57, Val loss: 0.57, Best Epoch: 50 (Val loss: 0.56) [val var: 0.19, min-max: 0.83-3.69]
# Epoch 54
# -------------------------------
# loss: 0.44 (@all: 0.99) mae: 0.56  [32/2218]
# loss: 0.78 (@all: 0.99) mae: 0.75  [352/2218]
# loss: 0.65 (@all: 0.99) mae: 0.64  [672/2218]
# loss: 0.42 (@all: 0.99) mae: 0.53  [992/2218]
# loss: 0.69 (@all: 0.99) mae: 0.70  [1312/2218]
# loss: 0.48 (@all: 0.99) mae: 0.58  [1632/2218]
# loss: 0.70 (@all: 0.99) mae: 0.70  [1952/2218]
# Train loss: 0.55, Val loss: 0.57, Best Epoch: 50 (Val loss: 0.56) [val var: 0.14, min-max: 1.34-4.07]
# Epoch 55
# -------------------------------
# loss: 0.87 (@all: 0.98) mae: 0.76  [32/2218]
# loss: 0.50 (@all: 0.98) mae: 0.58  [352/2218]
# loss: 0.40 (@all: 0.98) mae: 0.50  [672/2218]
# loss: 0.39 (@all: 0.98) mae: 0.53  [992/2218]
# loss: 0.37 (@all: 0.98) mae: 0.51  [1312/2218]
# loss: 0.64 (@all: 0.98) mae: 0.64  [1632/2218]
# loss: 0.57 (@all: 0.98) mae: 0.60  [1952/2218]
# Train loss: 0.56, Val loss: 0.56, Best Epoch: 55 (Val loss: 0.56) [val var: 0.16, min-max: 1.31-3.85]
# Epoch 56
# -------------------------------
# loss: 0.56 (@all: 0.98) mae: 0.57  [32/2218]
# loss: 0.84 (@all: 0.98) mae: 0.75  [352/2218]
# loss: 0.51 (@all: 0.97) mae: 0.61  [672/2218]
# loss: 0.58 (@all: 0.97) mae: 0.65  [992/2218]
# loss: 0.62 (@all: 0.97) mae: 0.66  [1312/2218]
# loss: 0.35 (@all: 0.97) mae: 0.48  [1632/2218]
# loss: 0.82 (@all: 0.97) mae: 0.72  [1952/2218]
# Train loss: 0.55, Val loss: 0.60, Best Epoch: 55 (Val loss: 0.56) [val var: 0.14, min-max: 1.52-4.23]
# Epoch 57
# -------------------------------
# loss: 0.91 (@all: 0.97) mae: 0.80  [32/2218]
# loss: 0.67 (@all: 0.97) mae: 0.68  [352/2218]
# loss: 0.74 (@all: 0.97) mae: 0.73  [672/2218]
# loss: 0.53 (@all: 0.97) mae: 0.59  [992/2218]
# loss: 0.58 (@all: 0.97) mae: 0.63  [1312/2218]
# loss: 0.56 (@all: 0.97) mae: 0.59  [1632/2218]
# loss: 0.81 (@all: 0.90) mae: 0.76  [992/2218]
# loss: 0.63 (@all: 0.90) mae: 0.63  [1312/2218]
# loss: 0.44 (@all: 0.90) mae: 0.55  [1632/2218]
# loss: 0.51 (@all: 0.90) mae: 0.59  [1952/2218]
# Train loss: 0.53, Val loss: 0.56, Best Epoch: 62 (Val loss: 0.56) [val var: 0.17, min-max: 1.37-3.94]
# Epoch 68
# -------------------------------
# loss: 0.42 (@all: 0.90) mae: 0.50  [32/2218]
# loss: 0.81 (@all: 0.90) mae: 0.73  [352/2218]
# loss: 0.58 (@all: 0.90) mae: 0.67  [672/2218]
# loss: 0.64 (@all: 0.90) mae: 0.62  [992/2218]
# loss: 0.24 (@all: 0.90) mae: 0.41  [1312/2218]
# loss: 0.64 (@all: 0.90) mae: 0.69  [1632/2218]
# loss: 0.48 (@all: 0.90) mae: 0.57  [1952/2218]
# Train loss: 0.54, Val loss: 0.56, Best Epoch: 62 (Val loss: 0.56) [val var: 0.18, min-max: 1.28-4.13]
# Epoch 69
# -------------------------------
# loss: 0.63 (@all: 0.90) mae: 0.65  [32/2218]
# loss: 0.67 (@all: 0.90) mae: 0.66  [352/2218]
# loss: 0.42 (@all: 0.89) mae: 0.52  [672/2218]
# loss: 0.47 (@all: 0.89) mae: 0.51  [992/2218]
# loss: 0.60 (@all: 0.89) mae: 0.61  [1312/2218]
# loss: 0.31 (@all: 0.89) mae: 0.46  [1632/2218]
# loss: 0.53 (@all: 0.89) mae: 0.56  [1952/2218]
# Train loss: 0.54, Val loss: 0.56, Best Epoch: 62 (Val loss: 0.56) [val var: 0.19, min-max: 1.33-4.11]
# Epoch 70
# -------------------------------
# loss: 0.51 (@all: 0.89) mae: 0.55  [32/2218]
# loss: 0.32 (@all: 0.89) mae: 0.44  [352/2218]
# loss: 0.54 (@all: 0.89) mae: 0.59  [672/2218]
# loss: 0.82 (@all: 0.89) mae: 0.73  [992/2218]
# loss: 0.47 (@all: 0.89) mae: 0.54  [1312/2218]
# loss: 0.62 (@all: 0.89) mae: 0.62  [1632/2218]
# loss: 0.63 (@all: 0.89) mae: 0.65  [1952/2218]
# Train loss: 0.54, Val loss: 0.55, Best Epoch: 70 (Val loss: 0.55) [val var: 0.17, min-max: 1.23-3.73]
# Epoch 71
# -------------------------------
# loss: 0.46 (@all: 0.89) mae: 0.56  [32/2218]
# loss: 0.34 (@all: 0.88) mae: 0.47  [352/2218]
# loss: 0.57 (@all: 0.88) mae: 0.62  [672/2218]
# loss: 0.49 (@all: 0.88) mae: 0.55  [992/2218]
# loss: 0.33 (@all: 0.88) mae: 0.49  [1312/2218]
# loss: 0.50 (@all: 0.88) mae: 0.57  [1632/2218]
# loss: 0.54 (@all: 0.88) mae: 0.57  [1952/2218]
# Train loss: 0.55, Val loss: 0.56, Best Epoch: 70 (Val loss: 0.55) [val var: 0.21, min-max: 1.14-3.93]
# Epoch 72
# -------------------------------
# loss: 0.53 (@all: 0.88) mae: 0.61  [32/2218]
# Train loss: 0.53, Val loss: 0.54, Best Epoch: 81 (Val loss: 0.54) [val var: 0.16, min-max: 1.22-3.68]
# Epoch 82
# -------------------------------
# loss: 0.51 (@all: 0.84) mae: 0.59  [32/2218]
# loss: 0.36 (@all: 0.84) mae: 0.46  [352/2218]
# loss: 0.53 (@all: 0.84) mae: 0.56  [672/2218]
# loss: 0.51 (@all: 0.84) mae: 0.59  [992/2218]
# loss: 0.60 (@all: 0.84) mae: 0.62  [1312/2218]
# loss: 0.41 (@all: 0.83) mae: 0.54  [1632/2218]
# loss: 0.63 (@all: 0.83) mae: 0.62  [1952/2218]
# Train loss: 0.52, Val loss: 0.54, Best Epoch: 82 (Val loss: 0.54) [val var: 0.15, min-max: 1.28-3.81]
# Epoch 83
# -------------------------------
# loss: 0.46 (@all: 0.83) mae: 0.56  [32/2218]
# loss: 0.99 (@all: 0.83) mae: 0.82  [352/2218]
# loss: 0.58 (@all: 0.83) mae: 0.57  [672/2218]
# loss: 0.30 (@all: 0.83) mae: 0.42  [992/2218]
# loss: 0.53 (@all: 0.83) mae: 0.55  [1312/2218]
# loss: 0.39 (@all: 0.83) mae: 0.49  [1632/2218]
# loss: 0.28 (@all: 0.83) mae: 0.45  [1952/2218]
# Train loss: 0.52, Val loss: 0.54, Best Epoch: 83 (Val loss: 0.54) [val var: 0.19, min-max: 1.31-3.88]
# Epoch 84
# -------------------------------
# loss: 0.61 (@all: 0.83) mae: 0.59  [32/2218]
# loss: 0.62 (@all: 0.83) mae: 0.62  [352/2218]
# loss: 0.48 (@all: 0.83) mae: 0.54  [672/2218]
# loss: 0.88 (@all: 0.83) mae: 0.80  [992/2218]
# loss: 0.52 (@all: 0.83) mae: 0.58  [1312/2218]
# loss: 0.59 (@all: 0.83) mae: 0.60  [1632/2218]
# loss: 0.45 (@all: 0.83) mae: 0.52  [1952/2218]
# Train loss: 0.53, Val loss: 0.58, Best Epoch: 83 (Val loss: 0.54) [val var: 0.17, min-max: 1.21-4.70]
# Epoch 85
# -------------------------------
# loss: 0.59 (@all: 0.83) mae: 0.65  [32/2218]
# loss: 0.66 (@all: 0.83) mae: 0.63  [352/2218]
# loss: 0.50 (@all: 0.83) mae: 0.54  [672/2218]
# loss: 0.39 (@all: 0.83) mae: 0.51  [992/2218]
# loss: 0.44 (@all: 0.83) mae: 0.56  [1312/2218]
# loss: 0.63 (@all: 0.82) mae: 0.66  [1632/2218]
# loss: 0.70 (@all: 0.82) mae: 0.68  [1952/2218]
# Train loss: 0.56, Val loss: 0.62, Best Epoch: 83 (Val loss: 0.54) [val var: 0.16, min-max: 1.28-4.72]
# Epoch 86
# -------------------------------
# loss: 0.29 (@all: 0.82) mae: 0.45  [32/2218]
# loss: 0.54 (@all: 0.82) mae: 0.58  [352/2218]
# loss: 0.64 (@all: 0.82) mae: 0.66  [672/2218]
# loss: 0.60 (@all: 0.82) mae: 0.60  [992/2218]
# loss: 0.44 (@all: 0.82) mae: 0.48  [1312/2218]
# loss: 0.35 (@all: 0.82) mae: 0.46  [1632/2218]
# loss: 0.63 (@all: 0.82) mae: 0.62  [1952/2218]
# Train loss: 0.51, Val loss: 0.54, Best Epoch: 86 (Val loss: 0.54) [val var: 0.16, min-max: 1.24-3.98]
# Epoch 87
# -------------------------------
# loss: 0.50 (@all: 0.82) mae: 0.55  [32/2218]
# loss: 0.56 (@all: 0.82) mae: 0.63  [352/2218]
# loss: 0.53 (@all: 0.82) mae: 0.57  [672/2218]
# loss: 0.49 (@all: 0.82) mae: 0.54  [992/2218]
# loss: 0.45 (@all: 0.82) mae: 0.54  [1312/2218]
# loss: 0.64 (@all: 0.82) mae: 0.66  [1632/2218]
# loss: 0.24 (@all: 0.82) mae: 0.39  [1952/2218]
# Train loss: 0.52, Val loss: 0.55, Best Epoch: 86 (Val loss: 0.54) [val var: 0.16, min-max: 1.25-4.28]
# Epoch 88
# -------------------------------
# loss: 0.41 (@all: 0.82) mae: 0.54  [32/2218]
# loss: 0.53 (@all: 0.82) mae: 0.57  [352/2218]
# loss: 0.47 (@all: 0.82) mae: 0.54  [672/2218]
# loss: 0.25 (@all: 0.81) mae: 0.40  [992/2218]
# loss: 0.38 (@all: 0.81) mae: 0.48  [1312/2218]
# loss: 0.65 (@all: 0.81) mae: 0.64  [1632/2218]
# loss: 0.54 (@all: 0.81) mae: 0.56  [1952/2218]
# Train loss: 0.52, Val loss: 0.56, Best Epoch: 86 (Val loss: 0.54) [val var: 0.15, min-max: 1.29-4.44]
# Epoch 89
# -------------------------------
# loss: 0.37 (@all: 0.81) mae: 0.50  [32/2218]
# loss: 0.37 (@all: 0.81) mae: 0.46  [352/2218]
# loss: 0.60 (@all: 0.81) mae: 0.61  [672/2218]
# loss: 0.43 (@all: 0.81) mae: 0.54  [992/2218]
# loss: 0.58 (@all: 0.81) mae: 0.59  [1312/2218]
# loss: 0.70 (@all: 0.81) mae: 0.67  [1632/2218]
# loss: 0.47 (@all: 0.81) mae: 0.51  [1952/2218]
# Train loss: 0.51, Val loss: 0.55, Best Epoch: 86 (Val loss: 0.54) [val var: 0.16, min-max: 1.28-4.55]
# Epoch 90
# -------------------------------
# loss: 0.48 (@all: 0.81) mae: 0.52  [32/2218]
# loss: 0.47 (@all: 0.81) mae: 0.54  [352/2218]
# loss: 0.69 (@all: 0.81) mae: 0.67  [672/2218]
# loss: 0.70 (@all: 0.81) mae: 0.67  [992/2218]
# loss: 0.33 (@all: 0.81) mae: 0.47  [1312/2218]
# loss: 0.53 (@all: 0.81) mae: 0.55  [1632/2218]
# loss: 0.38 (@all: 0.81) mae: 0.43  [1952/2218]
# Train loss: 0.52, Val loss: 0.54, Best Epoch: 86 (Val loss: 0.54) [val var: 0.18, min-max: 1.37-4.26]
# Epoch 91
# -------------------------------
# loss: 0.44 (@all: 0.81) mae: 0.54  [32/2218]
# loss: 0.31 (@all: 0.80) mae: 0.41  [352/2218]
# loss: 0.54 (@all: 0.80) mae: 0.59  [672/2218]
# loss: 0.42 (@all: 0.80) mae: 0.57  [992/2218]
# loss: 0.44 (@all: 0.77) mae: 0.49  [352/2218]
# loss: 0.30 (@all: 0.77) mae: 0.45  [672/2218]
# loss: 0.37 (@all: 0.77) mae: 0.49  [992/2218]
# loss: 0.44 (@all: 0.77) mae: 0.51  [1312/2218]
# loss: 0.47 (@all: 0.77) mae: 0.57  [1632/2218]
# loss: 0.68 (@all: 0.77) mae: 0.69  [1952/2218]
# Train loss: 0.50, Val loss: 0.52, Best Epoch: 100 (Val loss: 0.52) [val var: 0.16, min-max: 1.10-3.69]
# Epoch 102
# -------------------------------
# loss: 0.55 (@all: 0.77) mae: 0.58  [32/2218]
# loss: 0.41 (@all: 0.77) mae: 0.49  [352/2218]
# loss: 0.41 (@all: 0.77) mae: 0.51  [672/2218]
# loss: 0.59 (@all: 0.77) mae: 0.59  [992/2218]
# loss: 0.54 (@all: 0.77) mae: 0.57  [1312/2218]
# loss: 0.39 (@all: 0.77) mae: 0.48  [1632/2218]
# loss: 0.36 (@all: 0.77) mae: 0.47  [1952/2218]
# Train loss: 0.49, Val loss: 0.54, Best Epoch: 100 (Val loss: 0.52) [val var: 0.15, min-max: 1.11-3.96]
# Epoch 103
# -------------------------------
# loss: 0.48 (@all: 0.77) mae: 0.56  [32/2218]
# loss: 0.48 (@all: 0.76) mae: 0.57  [352/2218]
# loss: 0.34 (@all: 0.76) mae: 0.49  [672/2218]
# loss: 0.37 (@all: 0.76) mae: 0.50  [992/2218]
# loss: 0.50 (@all: 0.76) mae: 0.54  [1312/2218]
# loss: 0.40 (@all: 0.76) mae: 0.51  [1632/2218]
# loss: 0.46 (@all: 0.76) mae: 0.51  [1952/2218]
# ...
# Epoch 146
# -------------------------------
# loss: 0.20 (@all: 0.67) mae: 0.36  [32/2218]
# loss: 0.33 (@all: 0.67) mae: 0.40  [352/2218]
# loss: 0.47 (@all: 0.67) mae: 0.53  [672/2218]
# loss: 0.35 (@all: 0.67) mae: 0.45  [992/2218]
# loss: 0.42 (@all: 0.67) mae: 0.44  [1312/2218]
# loss: 0.48 (@all: 0.67) mae: 0.52  [1632/2218]
# loss: 0.27 (@all: 0.67) mae: 0.37  [1952/2218]
# Train loss: 0.38, Val loss: 0.42, Best Epoch: 146 (Val loss: 0.42) [val var: 0.23, min-max: 0.80-3.91]
# Epoch 147
# -------------------------------
# loss: 0.40 (@all: 0.67) mae: 0.49  [32/2218]
# loss: 0.36 (@all: 0.67) mae: 0.45  [352/2218]
# loss: 0.47 (@all: 0.67) mae: 0.50  [672/2218]
# loss: 0.23 (@all: 0.67) mae: 0.37  [992/2218]
# loss: 0.31 (@all: 0.67) mae: 0.45  [1312/2218]
# loss: 0.32 (@all: 0.67) mae: 0.43  [1632/2218]
# loss: 0.41 (@all: 0.67) mae: 0.48  [1952/2218]
# Train loss: 0.38, Val loss: 0.43, Best Epoch: 146 (Val loss: 0.42) [val var: 0.23, min-max: 0.80-4.20]
# Epoch 148
# -------------------------------
# loss: 0.42 (@all: 0.67) mae: 0.53  [32/2218]
# loss: 0.30 (@all: 0.67) mae: 0.39  [352/2218]
# loss: 0.73 (@all: 0.67) mae: 0.65  [672/2218]
# loss: 0.38 (@all: 0.67) mae: 0.47  [992/2218]
# loss: 0.29 (@all: 0.67) mae: 0.40  [1312/2218]
# loss: 0.65 (@all: 0.67) mae: 0.62  [1632/2218]
# loss: 0.36 (@all: 0.67) mae: 0.48  [1952/2218]
# Train loss: 0.38, Val loss: 0.43, Best Epoch: 146 (Val loss: 0.42) [val var: 0.23, min-max: 0.73-3.91]
# Epoch 149
# -------------------------------
# loss: 0.41 (@all: 0.67) mae: 0.47  [32/2218]
# loss: 0.30 (@all: 0.67) mae: 0.40  [352/2218]
# loss: 0.37 (@all: 0.67) mae: 0.47  [672/2218]
# loss: 0.20 (@all: 0.67) mae: 0.33  [992/2218]
# loss: 0.25 (@all: 0.67) mae: 0.36  [1312/2218]
# loss: 0.31 (@all: 0.67) mae: 0.40  [1632/2218]
# loss: 0.37 (@all: 0.66) mae: 0.48  [1952/2218]
# Train loss: 0.39, Val loss: 0.41, Best Epoch: 149 (Val loss: 0.41) [val var: 0.25, min-max: 0.81-3.72]
# Epoch 150
# -------------------------------
# loss: 0.65 (@all: 0.66) mae: 0.65  [32/2218]
# loss: 0.38 (@all: 0.66) mae: 0.47  [352/2218]
# loss: 0.53 (@all: 0.66) mae: 0.55  [672/2218]
# loss: 0.52 (@all: 0.66) mae: 0.49  [992/2218]
# loss: 0.33 (@all: 0.66) mae: 0.41  [1312/2218]
# loss: 0.33 (@all: 0.66) mae: 0.43  [1632/2218]
# loss: 0.32 (@all: 0.66) mae: 0.42  [1952/2218]
# Train loss: 0.38, Val loss: 0.41, Best Epoch: 150 (Val loss: 0.41) [val var: 0.24, min-max: 0.81-3.81]
# Epoch 151
# -------------------------------
# loss: 0.26 (@all: 0.66) mae: 0.40  [32/2218]
# loss: 0.39 (@all: 0.66) mae: 0.48  [352/2218]
# loss: 0.29 (@all: 0.66) mae: 0.40  [672/2218]
# loss: 0.31 (@all: 0.66) mae: 0.42  [992/2218]
# loss: 0.45 (@all: 0.66) mae: 0.52  [1312/2218]
# loss: 0.50 (@all: 0.66) mae: 0.52  [1632/2218]
# loss: 0.21 (@all: 0.66) mae: 0.35  [1952/2218]
# Train loss: 0.38, Val loss: 0.42, Best Epoch: 150 (Val loss: 0.41) [val var: 0.25, min-max: 0.81-3.81]
# Epoch 152
# -------------------------------
# loss: 0.28 (@all: 0.66) mae: 0.41  [32/2218]
# loss: 0.36 (@all: 0.66) mae: 0.45  [352/2218]
# loss: 0.46 (@all: 0.66) mae: 0.47  [672/2218]
# loss: 0.19 (@all: 0.66) mae: 0.33  [992/2218]
# loss: 0.68 (@all: 0.66) mae: 0.62  [1312/2218]
# loss: 0.55 (@all: 0.66) mae: 0.54  [1632/2218]
# loss: 0.32 (@all: 0.66) mae: 0.46  [1952/2218]
# Train loss: 0.40, Val loss: 0.44, Best Epoch: 150 (Val loss: 0.41) [val var: 0.27, min-max: 0.88-4.09]
# Epoch 153
# -------------------------------
# loss: 0.26 (@all: 0.66) mae: 0.40  [32/2218]
# loss: 0.29 (@all: 0.66) mae: 0.35  [352/2218]
# loss: 0.47 (@all: 0.66) mae: 0.54  [672/2218]
# loss: 0.36 (@all: 0.66) mae: 0.46  [992/2218]
# loss: 0.26 (@all: 0.66) mae: 0.43  [1312/2218]
# loss: 0.48 (@all: 0.66) mae: 0.50  [1632/2218]
# loss: 0.29 (@all: 0.66) mae: 0.44  [1952/2218]
# Train loss: 0.39, Val loss: 0.46, Best Epoch: 150 (Val loss: 0.41) [val var: 0.22, min-max: 0.92-4.27]
# Epoch 154
# -------------------------------
# loss: 0.25 (@all: 0.66) mae: 0.37  [32/2218]
# loss: 0.43 (@all: 0.66) mae: 0.49  [352/2218]
# loss: 0.30 (@all: 0.66) mae: 0.44  [672/2218]
# loss: 0.53 (@all: 0.66) mae: 0.58  [992/2218]
# loss: 0.56 (@all: 0.66) mae: 0.59  [1312/2218]
# loss: 0.34 (@all: 0.66) mae: 0.48  [1632/2218]
# loss: 0.44 (@all: 0.66) mae: 0.51  [1952/2218]
# Train loss: 0.38, Val loss: 0.41, Best Epoch: 154 (Val loss: 0.41) [val var: 0.24, min-max: 0.76-3.66]
# Epoch 155
# -------------------------------
# loss: 0.36 (@all: 0.66) mae: 0.45  [32/2218]
# loss: 0.46 (@all: 0.66) mae: 0.50  [352/2218]
# loss: 0.19 (@all: 0.66) mae: 0.34  [672/2218]
# loss: 0.29 (@all: 0.65) mae: 0.43  [992/2218]
# loss: 0.50 (@all: 0.65) mae: 0.56  [1312/2218]
# loss: 0.31 (@all: 0.65) mae: 0.45  [1632/2218]
# loss: 0.46 (@all: 0.65) mae: 0.52  [1952/2218]
# Train loss: 0.38, Val loss: 0.45, Best Epoch: 154 (Val loss: 0.41) [val var: 0.25, min-max: 0.77-4.63]
# Epoch 156
# -------------------------------
# loss: 0.55 (@all: 0.65) mae: 0.57  [32/2218]
# loss: 0.27 (@all: 0.65) mae: 0.35  [352/2218]
# loss: 0.25 (@all: 0.65) mae: 0.39  [672/2218]
# loss: 0.16 (@all: 0.65) mae: 0.30  [992/2218]
# loss: 0.44 (@all: 0.65) mae: 0.50  [1312/2218]
# loss: 0.41 (@all: 0.65) mae: 0.45  [1632/2218]
# loss: 0.28 (@all: 0.65) mae: 0.38  [1952/2218]
# Train loss: 0.40, Val loss: 0.43, Best Epoch: 154 (Val loss: 0.41) [val var: 0.25, min-max: 0.61-3.60]
# Epoch 157
# -------------------------------
# loss: 0.44 (@all: 0.65) mae: 0.47  [32/2218]
# loss: 0.63 (@all: 0.65) mae: 0.59  [352/2218]
# loss: 0.34 (@all: 0.65) mae: 0.48  [672/2218]
# loss: 0.44 (@all: 0.65) mae: 0.51  [992/2218]
# loss: 0.20 (@all: 0.65) mae: 0.34  [1312/2218]
# loss: 0.42 (@all: 0.65) mae: 0.47  [1632/2218]
# loss: 0.53 (@all: 0.65) mae: 0.54  [1952/2218]
# Train loss: 0.36, Val loss: 0.41, Best Epoch: 154 (Val loss: 0.41) [val var: 0.24, min-max: 0.71-3.81]
# Epoch 158
# -------------------------------
# loss: 0.24 (@all: 0.65) mae: 0.37  [32/2218]
# loss: 0.41 (@all: 0.65) mae: 0.49  [352/2218]
# loss: 0.47 (@all: 0.65) mae: 0.54  [672/2218]
# loss: 0.24 (@all: 0.65) mae: 0.35  [992/2218]
# loss: 0.83 (@all: 0.65) mae: 0.71  [1312/2218]
# loss: 0.35 (@all: 0.65) mae: 0.46  [1632/2218]
# loss: 0.20 (@all: 0.65) mae: 0.34  [1952/2218]
# Train loss: 0.37, Val loss: 0.42, Best Epoch: 154 (Val loss: 0.41) [val var: 0.25, min-max: 0.81-4.09]
# Epoch 159
# -------------------------------
# loss: 0.32 (@all: 0.65) mae: 0.41  [32/2218]
# loss: 0.36 (@all: 0.65) mae: 0.44  [352/2218]
# loss: 0.36 (@all: 0.65) mae: 0.46  [672/2218]
# loss: 0.26 (@all: 0.65) mae: 0.39  [992/2218]
# loss: 0.28 (@all: 0.65) mae: 0.37  [1312/2218]
# loss: 0.26 (@all: 0.65) mae: 0.40  [1632/2218]
# loss: 0.28 (@all: 0.65) mae: 0.39  [1952/2218]
# Train loss: 0.36, Val loss: 0.40, Best Epoch: 159 (Val loss: 0.40) [val var: 0.25, min-max: 0.74-3.64]
# Epoch 160
# -------------------------------
# loss: 0.38 (@all: 0.65) mae: 0.43  [32/2218]
# loss: 0.25 (@all: 0.65) mae: 0.36  [352/2218]
# loss: 0.39 (@all: 0.65) mae: 0.47  [672/2218]
# loss: 0.55 (@all: 0.65) mae: 0.59  [992/2218]
# loss: 0.50 (@all: 0.65) mae: 0.51  [1312/2218]
# loss: 0.36 (@all: 0.65) mae: 0.45  [1632/2218]
# loss: 0.27 (@all: 0.65) mae: 0.41  [1952/2218]
# Train loss: 0.36, Val loss: 0.42, Best Epoch: 159 (Val loss: 0.40) [val var: 0.26, min-max: 0.71-4.45]
# Epoch 161
# -------------------------------
# loss: 0.48 (@all: 0.65) mae: 0.52  [32/2218]
# loss: 0.59 (@all: 0.65) mae: 0.66  [352/2218]
# loss: 0.35 (@all: 0.64) mae: 0.48  [672/2218]
# loss: 0.39 (@all: 0.64) mae: 0.49  [992/2218]
# loss: 0.23 (@all: 0.64) mae: 0.34  [1312/2218]
# loss: 0.29 (@all: 0.64) mae: 0.41  [1632/2218]
# loss: 0.37 (@all: 0.64) mae: 0.48  [1952/2218]
# Train loss: 0.36, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.25, min-max: 0.72-3.80]
# Epoch 162
# -------------------------------
# loss: 0.21 (@all: 0.64) mae: 0.32  [32/2218]
# loss: 0.37 (@all: 0.64) mae: 0.47  [352/2218]
# loss: 0.21 (@all: 0.64) mae: 0.35  [672/2218]
# loss: 0.39 (@all: 0.64) mae: 0.48  [992/2218]
# loss: 0.34 (@all: 0.64) mae: 0.47  [1312/2218]
# loss: 0.34 (@all: 0.64) mae: 0.45  [1632/2218]
# loss: 0.65 (@all: 0.64) mae: 0.59  [1952/2218]
# Train loss: 0.35, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.74-4.07]
# Epoch 163
# -------------------------------
# loss: 0.22 (@all: 0.64) mae: 0.32  [32/2218]
# loss: 0.36 (@all: 0.64) mae: 0.44  [352/2218]
# loss: 0.33 (@all: 0.64) mae: 0.42  [672/2218]
# loss: 0.28 (@all: 0.64) mae: 0.42  [992/2218]
# loss: 0.42 (@all: 0.64) mae: 0.47  [1312/2218]
# loss: 0.41 (@all: 0.64) mae: 0.50  [1632/2218]
# loss: 0.22 (@all: 0.64) mae: 0.35  [1952/2218]
# Train loss: 0.36, Val loss: 0.44, Best Epoch: 159 (Val loss: 0.40) [val var: 0.27, min-max: 0.63-4.23]
# Epoch 164
# -------------------------------
# loss: 0.36 (@all: 0.64) mae: 0.43  [32/2218]
# loss: 0.33 (@all: 0.64) mae: 0.42  [352/2218]
# loss: 0.38 (@all: 0.64) mae: 0.46  [672/2218]
# loss: 0.51 (@all: 0.64) mae: 0.55  [992/2218]
# loss: 0.49 (@all: 0.64) mae: 0.53  [1312/2218]
# loss: 0.43 (@all: 0.64) mae: 0.43  [1632/2218]
# loss: 0.30 (@all: 0.64) mae: 0.38  [1952/2218]
# Train loss: 0.38, Val loss: 0.45, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.88-4.33]
# Epoch 165
# -------------------------------
# loss: 0.37 (@all: 0.64) mae: 0.48  [32/2218]
# loss: 0.25 (@all: 0.64) mae: 0.38  [352/2218]
# loss: 0.29 (@all: 0.64) mae: 0.38  [672/2218]
# loss: 0.37 (@all: 0.64) mae: 0.44  [992/2218]
# loss: 0.41 (@all: 0.64) mae: 0.46  [1312/2218]
# loss: 0.50 (@all: 0.64) mae: 0.58  [1632/2218]
# loss: 0.27 (@all: 0.64) mae: 0.36  [1952/2218]
# Train loss: 0.34, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.74-4.12]
# Epoch 166
# -------------------------------
# loss: 0.30 (@all: 0.64) mae: 0.43  [32/2218]
# loss: 0.26 (@all: 0.64) mae: 0.39  [352/2218]
# loss: 0.65 (@all: 0.64) mae: 0.60  [672/2218]
# loss: 0.36 (@all: 0.64) mae: 0.46  [992/2218]
# loss: 0.42 (@all: 0.64) mae: 0.53  [1312/2218]
# loss: 0.31 (@all: 0.64) mae: 0.44  [1632/2218]
# loss: 0.25 (@all: 0.64) mae: 0.39  [1952/2218]
# Train loss: 0.38, Val loss: 0.44, Best Epoch: 159 (Val loss: 0.40) [val var: 0.30, min-max: 0.88-4.27]
# Epoch 167
# -------------------------------
# loss: 0.41 (@all: 0.63) mae: 0.54  [32/2218]
# loss: 0.46 (@all: 0.63) mae: 0.53  [352/2218]
# loss: 0.29 (@all: 0.63) mae: 0.44  [672/2218]
# loss: 0.57 (@all: 0.63) mae: 0.52  [992/2218]
# loss: 0.42 (@all: 0.63) mae: 0.50  [1312/2218]
# loss: 0.28 (@all: 0.63) mae: 0.41  [1632/2218]
# loss: 0.40 (@all: 0.63) mae: 0.44  [1952/2218]
# Train loss: 0.34, Val loss: 0.42, Best Epoch: 159 (Val loss: 0.40) [val var: 0.29, min-max: 0.69-4.57]
# Epoch 168
# -------------------------------
# loss: 0.34 (@all: 0.63) mae: 0.46  [32/2218]
# loss: 0.19 (@all: 0.63) mae: 0.34  [352/2218]
# loss: 0.27 (@all: 0.63) mae: 0.43  [672/2218]
# loss: 0.30 (@all: 0.63) mae: 0.36  [992/2218]
# loss: 0.34 (@all: 0.63) mae: 0.43  [1312/2218]
# loss: 0.25 (@all: 0.63) mae: 0.36  [1632/2218]
# loss: 0.33 (@all: 0.63) mae: 0.41  [1952/2218]
# Train loss: 0.34, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.27, min-max: 0.72-4.16]
# Epoch 169
# -------------------------------
# loss: 0.35 (@all: 0.63) mae: 0.44  [32/2218]
# loss: 0.55 (@all: 0.63) mae: 0.54  [352/2218]
# loss: 0.38 (@all: 0.63) mae: 0.48  [672/2218]
# loss: 0.37 (@all: 0.63) mae: 0.45  [992/2218]
# loss: 0.36 (@all: 0.63) mae: 0.48  [1312/2218]
# loss: 0.46 (@all: 0.63) mae: 0.50  [1632/2218]
# loss: 0.28 (@all: 0.63) mae: 0.38  [1952/2218]
# Train loss: 0.34, Val loss: 0.43, Best Epoch: 159 (Val loss: 0.40) [val var: 0.27, min-max: 0.78-4.86]
# Epoch 170
# -------------------------------
# loss: 0.39 (@all: 0.63) mae: 0.46  [32/2218]
# loss: 0.26 (@all: 0.63) mae: 0.35  [352/2218]
# loss: 0.46 (@all: 0.63) mae: 0.53  [672/2218]
# loss: 0.32 (@all: 0.63) mae: 0.43  [992/2218]
# loss: 0.41 (@all: 0.63) mae: 0.47  [1312/2218]
# loss: 0.31 (@all: 0.63) mae: 0.41  [1632/2218]
# loss: 0.27 (@all: 0.63) mae: 0.40  [1952/2218]
# Train loss: 0.36, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.67-3.99]
# Epoch 171
# -------------------------------
# loss: 0.43 (@all: 0.63) mae: 0.45  [32/2218]
# loss: 0.43 (@all: 0.63) mae: 0.48  [352/2218]
# loss: 0.29 (@all: 0.63) mae: 0.43  [672/2218]
# loss: 0.35 (@all: 0.63) mae: 0.44  [992/2218]
# loss: 0.37 (@all: 0.63) mae: 0.50  [1312/2218]
# loss: 0.26 (@all: 0.63) mae: 0.33  [1632/2218]
# loss: 0.28 (@all: 0.63) mae: 0.42  [1952/2218]
# Train loss: 0.33, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.74-4.48]
# Epoch 172
# -------------------------------
# loss: 0.39 (@all: 0.63) mae: 0.47  [32/2218]
# loss: 0.38 (@all: 0.63) mae: 0.47  [352/2218]
# loss: 0.38 (@all: 0.63) mae: 0.47  [672/2218]
# loss: 0.59 (@all: 0.63) mae: 0.57  [992/2218]
# loss: 0.39 (@all: 0.63) mae: 0.48  [1312/2218]
# loss: 0.28 (@all: 0.63) mae: 0.39  [1632/2218]
# loss: 0.19 (@all: 0.63) mae: 0.34  [1952/2218]
# Train loss: 0.34, Val loss: 0.41, Best Epoch: 159 (Val loss: 0.40) [val var: 0.28, min-max: 0.71-4.16]
# Epoch 173
# -------------------------------
# loss: 0.29 (@all: 0.63) mae: 0.41  [32/2218]
# loss: 0.43 (@all: 0.62) mae: 0.51  [352/2218]
# loss: 0.27 (@all: 0.62) mae: 0.40  [672/2218]
# loss: 0.38 (@all: 0.62) mae: 0.46  [992/2218]
# loss: 0.27 (@all: 0.62) mae: 0.40  [1312/2218]
# loss: 0.41 (@all: 0.62) mae: 0.46  [1632/2218]
# loss: 0.48 (@all: 0.62) mae: 0.50  [1952/2218]
# Train loss: 0.34, Val loss: 0.42, Best Epoch: 159 (Val loss: 0.40) [val var: 0.30, min-max: 0.83-4.37]
# Epoch 174
# -------------------------------
# loss: 0.32 (@all: 0.62) mae: 0.41  [32/2218]
# loss: 0.28 (@all: 0.62) mae: 0.39  [352/2218]
# loss: 0.46 (@all: 0.62) mae: 0.53  [672/2218]
# loss: 0.20 (@all: 0.62) mae: 0.32  [992/2218]
# loss: 0.27 (@all: 0.62) mae: 0.37  [1312/2218]
# loss: 0.25 (@all: 0.62) mae: 0.35  [1632/2218]
# loss: 0.26 (@all: 0.62) mae: 0.38  [1952/2218]
# Train loss: 0.33, Val loss: 0.43, Best Epoch: 159 (Val loss: 0.40) [val var: 0.29, min-max: 0.73-4.79]
# Epoch 175
# -------------------------------
# loss: 0.22 (@all: 0.62) mae: 0.32  [32/2218]
# loss: 0.34 (@all: 0.62) mae: 0.43  [352/2218]
# loss: 0.37 (@all: 0.62) mae: 0.50  [672/2218]
# loss: 0.31 (@all: 0.62) mae: 0.39  [992/2218]
# loss: 0.51 (@all: 0.62) mae: 0.55  [1312/2218]
# loss: 0.38 (@all: 0.62) mae: 0.46  [1632/2218]
# loss: 0.44 (@all: 0.62) mae: 0.48  [1952/2218]
# Train loss: 0.33, Val loss: 0.43, Best Epoch: 159 (Val loss: 0.40) [val var: 0.29, min-max: 0.71-4.62]
# Epoch 176
# -------------------------------
# loss: 0.21 (@all: 0.62) mae: 0.35  [32/2218]
# loss: 0.41 (@all: 0.62) mae: 0.51  [352/2218]
# loss: 0.47 (@all: 0.62) mae: 0.54  [672/2218]
# loss: 0.23 (@all: 0.62) mae: 0.35  [992/2218]
# loss: 0.23 (@all: 0.62) mae: 0.37  [1312/2218]
# loss: 0.18 (@all: 0.62) mae: 0.31  [1632/2218]
# loss: 0.24 (@all: 0.62) mae: 0.37  [1952/2218]
# Train loss: 0.33, Val loss: 0.44, Best Epoch: 159 (Val loss: 0.40) [val var: 0.29, min-max: 0.80-4.91]
# Epoch 177
# -------------------------------
# loss: 0.23 (@all: 0.62) mae: 0.36  [32/2218]
# loss: 0.41 (@all: 0.62) mae: 0.46  [352/2218]
# loss: 0.46 (@all: 0.62) mae: 0.53  [672/2218]
# loss: 0.48 (@all: 0.62) mae: 0.49  [992/2218]
# loss: 0.39 (@all: 0.62) mae: 0.42  [1312/2218]
# loss: 0.22 (@all: 0.62) mae: 0.37  [1632/2218]
# loss: 0.45 (@all: 0.62) mae: 0.49  [1952/2218]
# Train loss: 0.34, Val loss: 0.43, Best Epoch: 159 (Val loss: 0.40) [val var: 0.30, min-max: 0.89-4.73]
# Epoch 178
# -------------------------------
# loss: 0.26 (@all: 0.62) mae: 0.38  [32/2218]
# loss: 0.46 (@all: 0.62) mae: 0.52  [352/2218]
# loss: 0.25 (@all: 0.62) mae: 0.35  [672/2218]
# loss: 0.49 (@all: 0.62) mae: 0.51  [992/2218]
# loss: 0.39 (@all: 0.62) mae: 0.50  [1312/2218]
# loss: 0.43 (@all: 0.62) mae: 0.48  [1632/2218]
# loss: 0.25 (@all: 0.62) mae: 0.41  [1952/2218]
# Train loss: 0.33, Val loss: 0.42, Best Epoch: 159 (Val loss: 0.40) [val var: 0.29, min-max: 0.65-4.11]
# Epoch 179
# -------------------------------
# loss: 0.36 (@all: 0.62) mae: 0.43  [32/2218]
# loss: 0.27 (@all: 0.62) mae: 0.39  [352/2218]
# loss: 0.21 (@all: 0.61) mae: 0.34  [672/2218]
# loss: 0.46 (@all: 0.61) mae: 0.49  [992/2218]
# loss: 0.31 (@all: 0.61) mae: 0.40  [1312/2218]
# loss: 0.12 (@all: 0.61) mae: 0.26  [1632/2218]
# loss: 0.29 (@all: 0.61) mae: 0.41  [1952/2218]
# Max patience reached, now loading the best checkpoint...
# Exiting...
# Parameters: 43045761.0

# %% [markdown]
# # Evaluation

# %%
predictions, labels = validate(fcnn, DataLoader(ImageDataset(pll_test, transform=cc_transform), batch_size=1), device="cpu")
print("Test loss", nn.L1Loss()(torch.Tensor(predictions), torch.Tensor(labels)).numpy())
pll_test["cnn"] = predictions
print(f"Predictions from: {pll_test.cnn.min():.2f} to {pll_test.cnn.max():.2f}, Var: {pll_test.cnn.var():.2f}")
print(f"MAE: {mean_absolute_error(labels, predictions):g}")
print(f"MSE: {mean_squared_error(labels, predictions):g}")
# Out:
# Test loss 0.5567008
# Predictions from: 1.06 to 3.76, Var: 0.21
# MAE: 0.556701
# MSE: 0.525809

# %%
gold_lbls = [int(l.numpy()) for l in labels]
pred_lbls = [int(p+0.25) for p in predictions]
print(classification_report(gold_lbls, pred_lbls))
ax = ConfusionMatrixDisplay.from_predictions(gold_lbls, pred_lbls, colorbar=False);
plt.tight_layout(); ax.figure_.savefig('confusion_fcnnr.pdf', format='PDF', dpi=300)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.20      0.30        35
#            2       0.51      0.91      0.66       121
#            3       0.76      0.37      0.50       103
#            4       0.00      0.00      0.00        19
#
#     accuracy                           0.56       278
#    macro avg       0.46      0.37      0.36       278
# weighted avg       0.58      0.56      0.51       278
